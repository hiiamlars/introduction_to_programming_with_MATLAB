# %% [markdown]
# <a href="https://colab.research.google.com/github/hiiamlars/Einfuehrung_in_die_Programmierung_mit_MATLAB/blob/main/data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initialize

# %%
# !pip install openai
# !pip install PyPDF2

import os

from google.colab import drive
drive.mount('/content/drive')

working_dir = "/content/drive/MyDrive/llmserver/task_iclr23/raw/"
dataset_dir = "/content/drive/MyDrive/llmserver/task_iclr23/dataset/"

os.makedirs(working_dir, exist_ok=True)
print(f"Ensured working directory exists at: {working_dir}.")

os.makedirs(dataset_dir, exist_ok=True)
print(f"Ensured dataset directory exists at: {dataset_dir}.")

pdf_dir = working_dir + "files/paper_pdf/"
os.makedirs(pdf_dir, exist_ok=True)
print(f"Ensured PDF download directory exists at: {pdf_dir}")

# %% [markdown]
# # Crawl Raw ICLR Data

# %%
import requests
import json
import os
import csv

BASE_URL = "https://api.openreview.net/notes?invitation=ICLR.cc/2023/Conference/-/Blind_Submission&details=directReplies"


def get_iclr_reviews(paper_info_filename=None, review_info_filename=None, decision_info_filename=None):
    offset = 0
    limit = 100  # number of paper per request
    max_limit = float('inf')
    paper_list = []
    review_list = []
    decision_list = []

    while offset + limit <= max_limit:
        print(f'Scraping review data: {offset}/{max_limit}')
        print("start request")
        response = requests.get(BASE_URL, params={"offset": offset, "limit": limit})
        print("end request")
        if response.status_code != 200:
            print("Error:", response.status_code)
            break

        data = response.json()
        if not data or 'notes' not in data or not data['notes']:
            break

        for note in data['notes']:
            paper = {}

            paper['uid'] = note['id']
            paper['number'] = note['number']
            paper['title'] = note['content']['title']
            paper['authors'] = note['content']['authors']
            paper['abstract'] = note['content']['abstract']
            paper['pdf'] = note['content']['pdf']
            paper['keywords'] = note['content']['keywords']

            if 'details' in note and 'directReplies' in note['details']:
                paper_list.append(paper)
                for directReplies in note['details']['directReplies']:


                    if directReplies['invitation'].endswith("Official_Review"):

                        review = {}
                        review['uid'] = directReplies['id']
                        review['paper_uid'] = paper['uid']
                        review['paper_title'] = paper['title']
                        review.update(directReplies['content'])

                        review_list.append(review)

                    if directReplies['invitation'].endswith("Decision"):

                        decision = {}
                        decision['uid'] = directReplies['id']
                        decision['paper_uid'] = paper['uid']
                        decision['paper_title'] = paper['title']
                        decision.update(directReplies['content'])

                        decision_list.append(decision)

        offset += limit


    with open(paper_info_filename, 'w', encoding = "utf-8") as f:
        json.dump(paper_list, f)
    with open(review_info_filename, 'w', encoding = "utf-8") as f:
        json.dump(review_list, f)
    with open(decision_info_filename, 'w', encoding = "utf-8") as f:
        json.dump(decision_list, f)


if __name__ == "__main__":
    os.makedirs(working_dir, exist_ok=True)
    get_iclr_reviews(paper_info_filename = working_dir + "ICLR2023paper_raw.json",
                     review_info_filename = working_dir + "ICLR2023review_raw.json",
                     decision_info_filename= working_dir + "ICLR2023decision_raw.json")

    print("Finished scraping ICLR 2023 reviews!")

# %% [markdown]
# # Build ICLR Raw Dataset

# %%
import os
import csv
import random
import json
import argparse
import unicodedata


def to_ascii(input_str):  # change the utf-8 characters to ascii
    assert(type(input_str) == str)
    normalized = unicodedata.normalize("NFKD", input_str)
    normalized = normalized.replace('"', "'")  # always use ' instead of " to avoid error in json
    ascii_str = "".join(c for c in normalized if c.isascii())
    return ascii_str


random.seed(19260817)
parser = argparse.ArgumentParser()
parser.add_argument("--topic", type=str, default="")
parser.add_argument("--max_count", type=int, default=10**9)
parser.add_argument("--input_paper", type=str, default=working_dir+"ICLR2023paper_raw.json")
parser.add_argument("--input_review", type=str, default=working_dir+"ICLR2023review_raw.json")
parser.add_argument("--dataset_name", type=str, required=True)
args = parser.parse_args(["--max_count","2000","--dataset_name","rand2000"])

# read businesses in full dataset, and then rename "uid" key to "id"
with open(args.input_paper, mode="r", encoding="utf-8") as json_file:
    papers = json.load(json_file)
review_cnt = {}
for paper in papers:
    paper["id"] = paper["uid"]  # rename "uid" -> "id"
    paper.pop("uid", None)
    paper["title"] = to_ascii(str(paper["title"]))
    paper["keywords"] = to_ascii(str(paper["keywords"]))
    paper["abstract"] = to_ascii(str(paper["abstract"]))
    review_cnt[paper["id"]] = 0

# read reviews in full dataset, and then rename "text" key to "review" and rename "business_id" key to "belong_id"
with open(args.input_review, mode="r", encoding="utf-8") as json_file:
    reviews = json.load(json_file)

review_format_str = '''Summary Of The Paper:

{}

Strength And Weaknesses:

{}

Clarity, Quality, Novelty And Reproducibility:

{}

Summary Of The Review:

{}
'''

for review in reviews:
    review["belong_id"] = review["paper_uid"]  # rename "business_id" -> "belong_id"
    review.pop("paper_uid", None)
    review["review"] = review_format_str.format(review["summary_of_the_paper"],review["strength_and_weaknesses"],review["clarity,_quality,_novelty_and_reproducibility"],review["summary_of_the_review"])
    review_cnt[review["belong_id"]] += 1

paper_selected = []
has = {}
for paper in papers:

    def contain_str(source, targets):
        # return whether any element in targets is a substring of source
        ## target is seperated by comma, e.g. "Food,Restaurants"
        ## use underline to represent space
        _source = source.lower()
        _targets = targets.lower().replace(" ", "").replace("_", " ").split(",")
        for _target in _targets:
            if _target in _source:
                return True
        return False

    def legal(paper):
        if review_cnt[paper["id"]] < 3: return False
        return contain_str(paper["title"] + paper["keywords"], args.topic)

    if legal(paper):

        paper_selected.append(paper)
        has[paper["id"]] = []

random.shuffle(paper_selected)
if len(paper_selected) > args.max_count:
    paper_selected = paper_selected[:args.max_count]

print("# items =", len(paper_selected))
with open(working_dir+"paper_"+args.dataset_name+".json","w",encoding="utf-8") as json_file:
    json.dump(paper_selected, json_file)

for i, review in enumerate(reviews):
    if review["belong_id"] in has:
        has[review["belong_id"]].append(i)
review_selected = []
for paper in paper_selected:
    for i in has[paper["id"]]:
        reviews[i]["review"] = to_ascii(reviews[i]["review"])
        review_selected.append(reviews[i])

print("# reviews =", len(review_selected))
with open(working_dir+"review_"+args.dataset_name+".json","w",encoding="utf-8") as json_file:
    json.dump(review_selected, json_file)

# %% [markdown]
# # Dataset Refinement

# %%
# @title Download Papers
import argparse
import threading
import time
import sys
import pandas as pd
import json
import os
import requests
import json
from tqdm.notebook import tqdm

parser = argparse.ArgumentParser()
# which context, see folder '../openreview/' for openreview and '../yelp/' for yelp
parser.add_argument("--context", type=str, default="openreview")
# which dataset, use 'rl' for openreview and 'pizza' for yelp.
parser.add_argument("--dataset", type=str, required=True)
args = parser.parse_args(["--dataset", "rand2000"])

with open(working_dir+"paper_"+args.dataset+".json", "r") as json_file:
    papers = json.load(json_file)
with open(working_dir+"review_"+args.dataset+".json", "r") as json_file:
    reviews = json.load(json_file)

def is_file_larger_than(path,lim): # 10 kb
    try:
        size = os.path.getsize(path)
        return size > lim
    except FileNotFoundError:
        return False

if __name__ == "__main__":

    for i, paper in enumerate(tqdm(papers, desc="Downloading Papers")):

        path_pdf = working_dir + "files/paper_pdf/" + paper["id"] + ".pdf"

        if not is_file_larger_than(path_pdf, 10*1024) :
            time.sleep(0.5)
            url = "https://openreview.net" + paper["pdf"]
            print(i, url)
            response = requests.get(url, proxies={"http": None, "https": None})

            if response.status_code == 200:
                with open(path_pdf, "wb") as file:
                    file.write(response.content)
            else:
                print("Failed to download the file. Status code:", response.status_code)
                time.sleep(2)
                response = requests.get(url, proxies={"http": None, "https": None})
                if response.status_code == 200:
                    with open(path_pdf, "wb") as file:
                        file.write(response.content)
                else:
                    print("Failed again:", response.status_code)
                    raise(Exception)
# Out:
# Downloading Papers:   0%|          | 0/2000 [00:00<?, ?it/s]
# 0 https://openreview.net/pdf/b7b54047fdaf97f505713a0b6675abc7e120c460.pdf
# 1 https://openreview.net/pdf/e0646a302829ac0b05b63973439d7651735a4498.pdf
# 2 https://openreview.net/pdf/20516df845666b5c362ac8bd1c616c7eb44ad606.pdf
# 3 https://openreview.net/pdf/043fba8d0ed8251ba2eb757665721e7fc496d839.pdf
# 4 https://openreview.net/pdf/106dc37f05b949150cc78b90e79512c41069b3a9.pdf
# 5 https://openreview.net/pdf/e48b4b7a07d7810a1f1175bb20762f88e7436ae8.pdf
# 6 https://openreview.net/pdf/98c0a5bad8225b6d1baf5c74047c4d04bacfcfa1.pdf
# 7 https://openreview.net/pdf/7cc43ee917a76ab228da527b72fbf90f70fb6608.pdf
# 8 https://openreview.net/pdf/375cd8060d66d3802592086cf8d856f477c86f39.pdf
# 9 https://openreview.net/pdf/49e74635805c5667e19c63ecaab734e6a4c18e0c.pdf
# 10 https://openreview.net/pdf/64363982c84b5f6eb48debf9bb39680c33562378.pdf
# 11 https://openreview.net/pdf/326a8562c6392857dcaaa121dcbbaaf8902b235f.pdf
# 12 https://openreview.net/pdf/ad0c6ee1a1c026a3dec4173db20dede07c063f3c.pdf
# 13 https://openreview.net/pdf/615dca2492e6011e963795b35cee509c95c1ac01.pdf
# 14 https://openreview.net/pdf/b8bbe368f67c756d1289de0bf523893e220e8eca.pdf
# 15 https://openreview.net/pdf/67efdb167b093600ea57b57653973a3eb44c3e42.pdf
# 16 https://openreview.net/pdf/c0cdcd692795c4d88b558b5b2ea56024167cbbf8.pdf
# 17 https://openreview.net/pdf/f86a805d1f98bbacca90bf4f817bcaa7fbcb8514.pdf
# 18 https://openreview.net/pdf/28a301002d2051863e11a107fa30929927e09e1c.pdf
# 19 https://openreview.net/pdf/d01af810369c47ba35939f31eeca144538d779b4.pdf
# 20 https://openreview.net/pdf/5ca6f1c5663b1746bbdd3e3caf6edb17b724dd80.pdf
# 21 https://openreview.net/pdf/6d8b8448984fff75216c098b5af97aae216580a4.pdf
# 22 https://openreview.net/pdf/af579d6de3f5c08eb2349d806a0120f8e6a3ac1f.pdf
# 23 https://openreview.net/pdf/3e531dec92de6b02fcbeef7a63d114423e73b571.pdf
# 24 https://openreview.net/pdf/a1d6e9f4add6577dd4a6d3d899e40db8cdda95d1.pdf
# 25 https://openreview.net/pdf/d67cf899be737e6e7275c4dc87dbaa672cccd517.pdf
# 26 https://openreview.net/pdf/b13f917e68703b3460499c90bda8ab8c71c42335.pdf
# 27 https://openreview.net/pdf/85aa404616e928e66f1999f72d19ae8d72364acd.pdf
# 28 https://openreview.net/pdf/e4f1f1f2fab151e29d1fce16a38e901fe0886ed9.pdf
# 29 https://openreview.net/pdf/bc171436c99bb31ea2d883553ed3204db027ced8.pdf
# 30 https://openreview.net/pdf/af859d60f1af73991c631bf27224a456c44ce94a.pdf
# 31 https://openreview.net/pdf/fedddd142f0627ab8151b2158be801f8e9c917c4.pdf
# 32 https://openreview.net/pdf/b8215e9ec231405a7f97d58eb05eb515dbef7abe.pdf
# 33 https://openreview.net/pdf/5a3189d05db84c9c4ef1ec27e2818e0fc6b45c40.pdf
# 34 https://openreview.net/pdf/11e4101c1705eaa7c0f4626439b493d3b84ed36e.pdf
# 35 https://openreview.net/pdf/ff5eb28555a5ba34f9012ebfe7bc894541f64303.pdf
# 36 https://openreview.net/pdf/524805ea0724c5cfd65a5c177a52782abf68bace.pdf
# 37 https://openreview.net/pdf/d3467a186dcd15df473440f6c24fe4d2d8f569c0.pdf
# 38 https://openreview.net/pdf/97d4ec3502e11b43bdc708cf3305416092c7863c.pdf
# 39 https://openreview.net/pdf/1570b427f34a06e453c22b559a7a9e632c36ec18.pdf
# 40 https://openreview.net/pdf/995a5bbd99f3f3968ff896af0f793d5a8f5ac6e9.pdf
# 41 https://openreview.net/pdf/4573656982162bf1565c7534c1ccbd83d8413272.pdf
# 42 https://openreview.net/pdf/8d7106908729c2d36678b74879e04ee16d9e147b.pdf
# 43 https://openreview.net/pdf/9c4b05e2de09add425cef7b86aeced27d31bfa87.pdf
# 44 https://openreview.net/pdf/560e13ad99c07d3ceaee8529d43bd2116b231755.pdf
# 45 https://openreview.net/pdf/7ef661bb7db09de434b36aea84e4c7f652c66c1f.pdf
# 46 https://openreview.net/pdf/482ad86253c266e9653c6f0f5b6b752b8ccd2ff6.pdf
# 47 https://openreview.net/pdf/8e53cd494ff16bfef607704574e7a1e2c770f607.pdf
# 48 https://openreview.net/pdf/cc4b6006471a5fcac57cbfcd5bb73ca9ef9b392f.pdf
# 49 https://openreview.net/pdf/d263b9c4283973a09247e2e1effd05f8d9bd7652.pdf
# 50 https://openreview.net/pdf/77e3d4474830ef1ec482bf7015ca9b61fa9f8264.pdf
# 51 https://openreview.net/pdf/44160e05022c0f1eeba06011cd69f40c1abe57b3.pdf
# 52 https://openreview.net/pdf/3a6b96056611c6b8f54d701c9aff85c3c2f71f79.pdf
# 53 https://openreview.net/pdf/cad83237af6ddb0e9d1ec444c3e8c113cb2d4916.pdf
# 54 https://openreview.net/pdf/97091df5f130c0de6e4c2a5ad6764792cd89ed03.pdf
# 55 https://openreview.net/pdf/7950e98392d8acae0f8b9ad4025629b7b4836313.pdf
# 56 https://openreview.net/pdf/02e474db582dabb8035ed3b2279cdfdad46dca9f.pdf
# 57 https://openreview.net/pdf/1e66fdaab805cebe5a84c568baa5b2a817e6b6f3.pdf
# 58 https://openreview.net/pdf/fcc6fac07b7ce1bf94ac3f39dfa76d542e753c54.pdf
# 59 https://openreview.net/pdf/4120f135fba7001a85237ce4a81740c0626abb31.pdf
# 60 https://openreview.net/pdf/b7c35e63818d65e4523a6ae4314674a0eeb7bb36.pdf
# 61 https://openreview.net/pdf/762770bc48f41ed202ffb6be40f0058989516d0f.pdf
# 62 https://openreview.net/pdf/2e551aaf5e4f3d5a15272f0f78bcaf860e9cb8bd.pdf
# 63 https://openreview.net/pdf/e4423008f644bc87714ab4d1c2b3ed7e37ac77d2.pdf
# 64 https://openreview.net/pdf/33c05b0bd300e12f24e2ac7a85f4716f5c4a9147.pdf
# 65 https://openreview.net/pdf/023ccc20cede95d1badbb20f946eb68ff8bd7ed1.pdf
# 66 https://openreview.net/pdf/8d310f20e54ef071f9265cf12cf4959583d516b3.pdf
# 67 https://openreview.net/pdf/e1a0ac295d7e905fb72e78968e396731ad364a0b.pdf
# 68 https://openreview.net/pdf/0b66ee85570b37447468b69901fd9efa9d4da5dc.pdf
# 69 https://openreview.net/pdf/dff9cd52231a7157d98d0716e640f522b208db74.pdf
# 70 https://openreview.net/pdf/dc00572cbf1ba37d6927b5663d6ca68300b6678e.pdf
# 71 https://openreview.net/pdf/eee00e0f0cb28195c27021a65f0e3566f79dbb60.pdf
# 72 https://openreview.net/pdf/21d61c913c546d572488600f61aeaeb4ae075dec.pdf
# 73 https://openreview.net/pdf/fc75e551b78aa6c9f0d17f3b6e8627d42d495923.pdf
# 74 https://openreview.net/pdf/ea6946cc1e63e2067130c3c79c0b89cdb7dad2a4.pdf
# 75 https://openreview.net/pdf/306873f49807d6dc86cd1e12fd698c00d2f3123a.pdf
# 76 https://openreview.net/pdf/2607a064389bdde9d47bd61f38b952fb58cb49c2.pdf
# 77 https://openreview.net/pdf/b982ed337b6c3ff43fb3fa4e63f9492b31f03e06.pdf
# 78 https://openreview.net/pdf/a1b6ae5c041645625de45e46ad10cdde373f930c.pdf
# 79 https://openreview.net/pdf/49df0d6bae0a281b3f3909c9502726540aa5cf3a.pdf
# 80 https://openreview.net/pdf/013cd54124218f33d37316602e1e2a757f1df1f2.pdf
# 81 https://openreview.net/pdf/62b125792eabd26dabe695ba7886d7df4261dfa1.pdf
# 82 https://openreview.net/pdf/374c9ac59ff86090712676f28b7100fc83ff8705.pdf
# 83 https://openreview.net/pdf/a33a54dc51ae12d26281cd196933bb3be33a76f3.pdf
# 84 https://openreview.net/pdf/72b6c6490682e3c76c05ac73a2ac11d385061e21.pdf
# 85 https://openreview.net/pdf/6bd7177a33fed4da74d010246448583573fa2c48.pdf
# 86 https://openreview.net/pdf/0776550849b74d70586738db037bf1c9e9707c63.pdf
# 87 https://openreview.net/pdf/94ddddee68e974505f45bc9249fcd649c1167f2c.pdf
# 88 https://openreview.net/pdf/842fc5862fdc3cf810d4bbb472afb682c6068a58.pdf
# 89 https://openreview.net/pdf/dd3b89b75d6fb64f4ccab33719382149f2f789ff.pdf
# 90 https://openreview.net/pdf/2bcffe27e982ea323f59ee62f175ae43573b76f7.pdf
# 91 https://openreview.net/pdf/3e093a06f59d08ce678211a216d45a588fcf44f7.pdf
# 92 https://openreview.net/pdf/ee4dce013cdb125a610759d64c058b9dd35caa6e.pdf
# 93 https://openreview.net/pdf/1297e3fec8dd4a980666cce03de07123009695b3.pdf
# 94 https://openreview.net/pdf/0f171c08e3834071881a6b58bb7aff18e4aadee1.pdf
# 95 https://openreview.net/pdf/2746ec6d86ab529b37c8f7c1efff4136d5e79bab.pdf
# 96 https://openreview.net/pdf/bd807c71b5364b2a18c5d5a0b811e7462a39d6b7.pdf
# 97 https://openreview.net/pdf/0b868656c3c81251d630f14b279b8a9fa51de107.pdf
# 98 https://openreview.net/pdf/494e815d166428fb0069b16709c2eb5a2310063a.pdf
# 99 https://openreview.net/pdf/0f568427fb05b2660614b52c5f8dab551fc4d702.pdf
# 100 https://openreview.net/pdf/f7b3eb377fe48395fbc3bef3f28c62907e51ee45.pdf
# 101 https://openreview.net/pdf/193b1896055f351c318c15dfb18834d06de13f97.pdf
# 102 https://openreview.net/pdf/666b0c25d52a00936dff3dd3d4402cdbbcef044e.pdf
# 103 https://openreview.net/pdf/fc91c5266695fec4a2e41f98930228517f9faa06.pdf
# 104 https://openreview.net/pdf/9613756cf1120673911f4df570303c2be4809c3b.pdf
# 105 https://openreview.net/pdf/6507802ca7e95e60abfdd3910aaefa5450193400.pdf
# 106 https://openreview.net/pdf/0e0f4c80c56d0d57f3f758fa07e6f2226ddefea8.pdf
# 107 https://openreview.net/pdf/320b9e4d925b6428835f0cb0578b08690fd3cc0d.pdf
# 108 https://openreview.net/pdf/42d0d7a000ea7c23564608ca1c3fcc8579656534.pdf
# 109 https://openreview.net/pdf/5c2a0ddd8a652ab99b14ffd766607bb364e763b9.pdf
# 110 https://openreview.net/pdf/f8d4405c38abdedde2df14b73a10ff863e6d025e.pdf
# 111 https://openreview.net/pdf/1b1f519f5e078a6bde6efcfd6d0f843c6aadffbc.pdf
# 112 https://openreview.net/pdf/93057b069249052b768c5bd8ee430d74eca47da8.pdf
# 113 https://openreview.net/pdf/838b0cc14e436d9819a99a150de8b7adc2d00425.pdf
# 114 https://openreview.net/pdf/8f3d206a3499ff07ce036109c750a257444d22a8.pdf
# 115 https://openreview.net/pdf/3ae69c7520530175437af21413eceb63b3e6dbcc.pdf
# 116 https://openreview.net/pdf/9a2724f6f528a7407c666e3436dcab690f305478.pdf
# 117 https://openreview.net/pdf/6c5914ffbccd510000a84a0f0aad7cb9fdfbf835.pdf
# 118 https://openreview.net/pdf/e3d05b61f28245c5bfd094687e14b42cc151ed76.pdf
# 119 https://openreview.net/pdf/2247e7c663e56434e86aa61a961767bcfb97995d.pdf
# 120 https://openreview.net/pdf/f85ad885376722f740ab9f661f2599ae480d5a3d.pdf
# 121 https://openreview.net/pdf/2b5ae3634984ff91c4fcf9eb1459796fad4bb8bf.pdf
# 122 https://openreview.net/pdf/3d748072189f631dccc0d79e113d3909f32f78b5.pdf
# 123 https://openreview.net/pdf/9aad6512d20e60b2271f37500940f999ba2677aa.pdf
# 124 https://openreview.net/pdf/fc5d88df1a06d30ae79fb23e87030f0fb2c8bd76.pdf
# 125 https://openreview.net/pdf/4ec08e473927b03aa7f8de8ba1cbc82cdecc6501.pdf
# 126 https://openreview.net/pdf/89dbebc8608b7115596225380f7f411d9c944eaf.pdf
# 127 https://openreview.net/pdf/daadbc20b5665f981c5c27eeb20cb5e9ba6ac96e.pdf
# 128 https://openreview.net/pdf/254ceea5835dc90c9549185f3cb68445db58d846.pdf
# 129 https://openreview.net/pdf/0e8422f2a0c81b5b15c342fcd297e5f044c82a1b.pdf
# 130 https://openreview.net/pdf/9799927d23eaa99c92dba0a83c8b164ffb19ff97.pdf
# 131 https://openreview.net/pdf/d4e8e9e71eb8c7b7f49164daa7d89ed12538df19.pdf
# 132 https://openreview.net/pdf/0bed689d4b0c72cb2f2561862218853290e48ce5.pdf
# 133 https://openreview.net/pdf/090b4b0ec856b04f45884d46e851b8ee2a8ee404.pdf
# 134 https://openreview.net/pdf/91f1c96de0279c81fb44166262ba54d69daf0fe4.pdf
# 135 https://openreview.net/pdf/819931d42f21507778b32c40483a50638ce89903.pdf
# 136 https://openreview.net/pdf/a96a1f9b1547d4f0c5db1e0faf80244de4de3293.pdf
# 137 https://openreview.net/pdf/a8bec8cbc82491f74fd513f2cdc63f82f5795518.pdf
# 138 https://openreview.net/pdf/24823d84c68d2321555336724867855b12d26d31.pdf
# 139 https://openreview.net/pdf/13ffd12c10fe5d7438cbf86c90578f7e03a718c2.pdf
# 140 https://openreview.net/pdf/0b3476b020632fa0b827e5fd75eadb6e8509896a.pdf
# 141 https://openreview.net/pdf/cba18f4378f68893c8318b6b38f2b0d403d86cef.pdf
# 142 https://openreview.net/pdf/a18e9e8d17f6440007598d9afb6b22a09956568c.pdf
# 143 https://openreview.net/pdf/eea73f7fc60694325dc6eb8762ebf6bc3bffcf2a.pdf
# 144 https://openreview.net/pdf/a0dccf940ce72701ae54079adff6bce5cc238206.pdf
# 145 https://openreview.net/pdf/c8f0e18f77fe43fa9c5165846d4b0af760612bf4.pdf
# 146 https://openreview.net/pdf/1b85540a8b32309c687816179212a1c92926443c.pdf
# 147 https://openreview.net/pdf/e5091cb97519dcf5d2bac76df947740b93fbf898.pdf
# 148 https://openreview.net/pdf/a7d8770204585fd9a6f3c6695c41a197bea3924a.pdf
# 149 https://openreview.net/pdf/b76de0f572f704575f927eccbbb6c0031f8b7427.pdf
# 150 https://openreview.net/pdf/b308a284126f7085845770ca2eddcebeb7ec2979.pdf
# 151 https://openreview.net/pdf/7b1fa6ddb8a0a13864f94d60cd015ca2274147b9.pdf
# 152 https://openreview.net/pdf/4ea61cbdee2b654aeffc24f7d5a2fcaef90a7677.pdf
# 153 https://openreview.net/pdf/51ac4edb4190ad35714af50c5385b78e0c60c5f8.pdf
# 154 https://openreview.net/pdf/1044be229fce7e0ca0d3d6b5b2352b94f3f02fb9.pdf
# 155 https://openreview.net/pdf/ee5c222d76dee2155c9e5e5058f2ded043e2e3f5.pdf
# 156 https://openreview.net/pdf/0ab315bee6f442f8432a770dc489694d159af978.pdf
# 157 https://openreview.net/pdf/ea2e79062b1cbfa81d563a7aaca825e29af61b91.pdf
# 158 https://openreview.net/pdf/826efb580419b89e9ce1db3a7c676c7010ebe04b.pdf
# 159 https://openreview.net/pdf/dc48bec9c7acf3125dddc466e509d7652cdeed79.pdf
# 160 https://openreview.net/pdf/3943d2638f2adc77b54de624c3d14c17ee8615f8.pdf
# 161 https://openreview.net/pdf/c24029cc804db4275f93cef93be5f36179e5958c.pdf
# 162 https://openreview.net/pdf/5e61c791e669ce20ef63b9207e7f9f9d6c650f23.pdf
# 163 https://openreview.net/pdf/df967fe60a20e0e304bd72e03f2bf158f3c30311.pdf
# 164 https://openreview.net/pdf/7cdbfadf791070fa900d133875a81569b8579a5b.pdf
# 165 https://openreview.net/pdf/7d55c1ef958f28c6040561ea0d9554ad3386bbc3.pdf
# 166 https://openreview.net/pdf/b51d5d9398934da9dd8dcfa5636d9d2c50e068e0.pdf
# 167 https://openreview.net/pdf/4b32546e4d1bbd77894db3e59a88d2731f1e53b2.pdf
# 168 https://openreview.net/pdf/14392e7c217114a74674c714c248cd648e9b92d3.pdf
# 169 https://openreview.net/pdf/ef01dfd6be4a5a8a5e656b07ffa7a26422962773.pdf
# 170 https://openreview.net/pdf/7a91a6c886613eb16a11a8642f19d57dc97b282b.pdf
# 171 https://openreview.net/pdf/de519dcd87aa63db98b0621cfd16b7f18e173342.pdf
# 172 https://openreview.net/pdf/cbb623c131dfcde5c6d1c18ce45b5b316c7b6beb.pdf
# 173 https://openreview.net/pdf/ea9302d6a170b14b0789476bf9046e4f734f87ca.pdf
# 174 https://openreview.net/pdf/a6183238f253e4f0e0832db2109484908c431cbe.pdf
# 175 https://openreview.net/pdf/88ef1cfb9bb4cc5968403a8231f73c3ab233d413.pdf
# 176 https://openreview.net/pdf/c29b36c06fd3175639e80ff30178fad03267ce5c.pdf
# 177 https://openreview.net/pdf/1240f349d491e95499f0c82e7a0de39047d53f8e.pdf
# 178 https://openreview.net/pdf/55ff81865002568b6dec878351a2ebc6c907fa12.pdf
# 179 https://openreview.net/pdf/214dd3d4f346964ae17621ab8b33fe8cd5a4a444.pdf
# 180 https://openreview.net/pdf/7399276efc2d9eb8ae74a790e054008f752b84b5.pdf
# 181 https://openreview.net/pdf/8cfc259b7bd52dd062abbfdf800fc63779766d37.pdf
# 182 https://openreview.net/pdf/e4da1f4c2b060375df4f5a1488aadc1d7a135c64.pdf
# 183 https://openreview.net/pdf/f8bd02450e258477f763e4da306000d5a558577d.pdf
# 184 https://openreview.net/pdf/bfb992bb824c13285ca88bca7b97ffe32757c4a3.pdf
# 185 https://openreview.net/pdf/e238ee382bad7d00c5bdd8b574be602c3ccdb90a.pdf
# 186 https://openreview.net/pdf/a8f9b8a534fa8b127d5f6ab15346b5ba982885c3.pdf
# 187 https://openreview.net/pdf/a94453ff77ae07b1286d0a55997765eaef20b48e.pdf
# 188 https://openreview.net/pdf/4fc22cb9d6d8f26d83b6ff14379f6e08f167c4c2.pdf
# 189 https://openreview.net/pdf/54b7911797398691422146138209e69d0674e5de.pdf
# 190 https://openreview.net/pdf/3ab06ee9ce85788c655c90e5b72f783423f1d60f.pdf
# 191 https://openreview.net/pdf/a5c1d6dcdd8cc221428ba2d2ca0ae27b5526f529.pdf
# 192 https://openreview.net/pdf/777e77789f1c42cdba4f79aa6b5ffdc035bef8f5.pdf
# 193 https://openreview.net/pdf/58fcd211906a7adcd7ef5949496ec5ff663da9d6.pdf
# 194 https://openreview.net/pdf/bdf1e70046944ab415846933f91d797df8ebf754.pdf
# 195 https://openreview.net/pdf/8bc5b08facc9645742f1af7a4746ea122a9645a2.pdf
# 196 https://openreview.net/pdf/d6c12fbe2df297c72e84697ebb41ab9e58845b31.pdf
# 197 https://openreview.net/pdf/1f70add33d89167e0abad3640d14807aa9595389.pdf
# 198 https://openreview.net/pdf/bbfb043e9e7e517f2ca5901238e45aabf2a6da33.pdf
# 199 https://openreview.net/pdf/6f5a5cc901f4374655d80206bf3de64255d24460.pdf
# 200 https://openreview.net/pdf/1b652f4ee2aba1681f8d0e268557ff8ce743d37d.pdf
# 201 https://openreview.net/pdf/f59af5cdac21ab98d3b6f10926ac7ebaa1e3ce40.pdf
# 202 https://openreview.net/pdf/f3d22d205a655605ec39b18c7f1ae329ffcf896d.pdf
# 203 https://openreview.net/pdf/febbb9ca1347007cbc1d17eb1d524c9f09725ced.pdf
# 204 https://openreview.net/pdf/e3ebc4afb3c3051ac2670b1f21a54881897fe728.pdf
# 205 https://openreview.net/pdf/dfe178dba8af2855569d8f59cd99c5d536de4408.pdf
# 206 https://openreview.net/pdf/3f0a3f273387e4dd7f3e95ec7b721806df4c1623.pdf
# 207 https://openreview.net/pdf/dc65a296db7555c082ecb0013655b03002dc5e39.pdf
# 208 https://openreview.net/pdf/70b7c8efcb690e77a2ae3aeac0944a66253f5a01.pdf
# 209 https://openreview.net/pdf/af003b0efd5e0b85ae3ae340fe13f008a792a24b.pdf
# 210 https://openreview.net/pdf/57b66dce7d9597251b44d2a33e727e01c48bd036.pdf
# 211 https://openreview.net/pdf/eaf0d6ae5cbcc76e626aef7d8b1df2b919b74633.pdf
# 212 https://openreview.net/pdf/9e0c9a22624b5eddabce80e7ca2d8b809a41a130.pdf
# 213 https://openreview.net/pdf/64391bc90f43aa535210009ca690b41064858cf1.pdf
# 214 https://openreview.net/pdf/38a40982d992b10fb502a87d04a9adc6562770c0.pdf
# 215 https://openreview.net/pdf/090c1fa0cc728fa6eb032fe3c74b8b5125be7e94.pdf
# 216 https://openreview.net/pdf/b41256b2ee29f6e5ec3e51cca015a39d47426eab.pdf
# 217 https://openreview.net/pdf/03a33d203caf7979df26f3ebab0d6f6541519e4a.pdf
# 218 https://openreview.net/pdf/bb170de971ade1773293d4ad37a9265d38df34db.pdf
# 219 https://openreview.net/pdf/764ef627c615ab06189b497ca625de7650931d6f.pdf
# 220 https://openreview.net/pdf/190e801aceaf60174555a92c2de693d6aafaa8f6.pdf
# 221 https://openreview.net/pdf/11e312efbafdf40fdeb15681fb00b67fdd6a0114.pdf
# 222 https://openreview.net/pdf/00599853de2618a03c95b10d71e6063c0cd2ecca.pdf
# 223 https://openreview.net/pdf/258fb90b4016055d67f189df87dbcb9c85c97020.pdf
# 224 https://openreview.net/pdf/4d9568f7c1bcbd5194267d1a5490e35aac791b4a.pdf
# 225 https://openreview.net/pdf/a0a8d265db66af337c341b79890e1383d3b6fe90.pdf
# 226 https://openreview.net/pdf/91dc3839c436b85ece9f4387c8f1b45a9decc68e.pdf
# 227 https://openreview.net/pdf/ca3279793d6aead584a3cc1d0742bfec8b2f2f89.pdf
# 228 https://openreview.net/pdf/d6acf08fb5af0b46b4e370411608acccd29fbc82.pdf
# 229 https://openreview.net/pdf/00006db720cb6633b7bbc9ff4847f8a9b83d14f5.pdf
# 230 https://openreview.net/pdf/4eb28b6c9acc4389765a76e4f9d9e95745d69999.pdf
# 231 https://openreview.net/pdf/bd1bd4cde5a7030a3caf47dd561d77d09137fb45.pdf
# 232 https://openreview.net/pdf/c7a0634a0a714037bf12d6315b863ca883f95c05.pdf
# 233 https://openreview.net/pdf/2d1c30475b7e47aaec4402b7ffd940072d10b35d.pdf
# 234 https://openreview.net/pdf/950a3e8b6cd8b8caf1158dee598f46aabdf6e59d.pdf
# 235 https://openreview.net/pdf/47ff06773ffd6757c65cd362fde9c7bfd3176168.pdf
# 236 https://openreview.net/pdf/58c155b8082b3366c06a92d24d638d198650fb53.pdf
# 237 https://openreview.net/pdf/c54650701a3023e84ebf4ae863c2ccf168538608.pdf
# 238 https://openreview.net/pdf/de05c291aec0b3537816d680f0e22fdab468a85e.pdf
# 239 https://openreview.net/pdf/9d7d628b03c158090ad65049eed713a3eef49ed2.pdf
# 240 https://openreview.net/pdf/4f07c7b6fea42534db8640c840402f6d066a8bd5.pdf
# 241 https://openreview.net/pdf/58588985182b7adae53071aa8b2da82ff6db8141.pdf
# 242 https://openreview.net/pdf/334c209b6add8bd79f1a1215dd53f499db9698e8.pdf
# 243 https://openreview.net/pdf/3b5bf7c992474c93c625152014c3df1632a2d379.pdf
# 244 https://openreview.net/pdf/a9d186e4ee1859097ef388e218639a4a12bee126.pdf
# 245 https://openreview.net/pdf/082ae9856f805df99b2abe0f422e94e79c2f5733.pdf
# 246 https://openreview.net/pdf/82bcf0c397be1c3af9632eb731b60448f8cf1223.pdf
# 247 https://openreview.net/pdf/919643bcc69293d00b131da05256a2e454fc8f04.pdf
# 248 https://openreview.net/pdf/a884fb4472a1fc8b87939a66b77c6d73819848b2.pdf
# 249 https://openreview.net/pdf/b7219af3a9c6c0c0add8ae9fa74bae7fd3cc27f6.pdf
# 250 https://openreview.net/pdf/d693e0ef8d0dfd32267ebca927cbf2cc3fce9f3a.pdf
# 251 https://openreview.net/pdf/0b88dbf1d08790a512a587e20d57a19dea822933.pdf
# 252 https://openreview.net/pdf/ca6e4f76d7f82cce8b1714f55f233acdfc17aa86.pdf
# 253 https://openreview.net/pdf/6b566de37f3281e3a1bec3d36af62f11b72f4fc5.pdf
# 254 https://openreview.net/pdf/5bcb50e805c33efcdf74c6d29f9b1a989b7f43b8.pdf
# 255 https://openreview.net/pdf/318115286f07cfda977b9ade502830c961c8a335.pdf
# 256 https://openreview.net/pdf/0c900b18137ea74d6ca0a934667ba24676032540.pdf
# 257 https://openreview.net/pdf/fb8cb9c0430aa29664c0a8339ed19eaa2ab5d855.pdf
# 258 https://openreview.net/pdf/5ee408c0c749bc86351dde2589bdd8c61cd52215.pdf
# 259 https://openreview.net/pdf/0ffbc09764bcd3fed340d49d2404429bae5277f5.pdf
# 260 https://openreview.net/pdf/6e3044ae6e9494f027b7c011f97efa8f0ed029c0.pdf
# 261 https://openreview.net/pdf/f73064906e38441e21dd0a622065469ef3f5b5bd.pdf
# 262 https://openreview.net/pdf/886b111245a62475dbb583ff62cfb49d0fbbc5c3.pdf
# 263 https://openreview.net/pdf/3f51822f4013fda1f2419f4e5753b3a31d1faa31.pdf
# 264 https://openreview.net/pdf/a12f07aece7eab0ba1d613320c60aa1d3c8acc41.pdf
# 265 https://openreview.net/pdf/a180ff20bf660bc9f8a2f007193ed71e83ba91f7.pdf
# 266 https://openreview.net/pdf/1407b7dbd7010687170a8c35b2ecf337ab3a0929.pdf
# 267 https://openreview.net/pdf/b719e63b370e71f25e26536d50136c439e0ea583.pdf
# 268 https://openreview.net/pdf/aa9ef4d767b4a4bda1b769e885e5a15da0aac3a0.pdf
# 269 https://openreview.net/pdf/c48c0d9c5389ecab0650d9039f11a47231ea14fd.pdf
# 270 https://openreview.net/pdf/668ef1e66f349e87c8948f0e5e5984608ebef31d.pdf
# 271 https://openreview.net/pdf/1ff6acd0e12904ca82c160b68cb95e823d7c9a36.pdf
# 272 https://openreview.net/pdf/d01a52f2b56897d5d510f0aa22714948331c66d0.pdf
# 273 https://openreview.net/pdf/ace015edbe847d04dc86cb008bdbe3451ffa804c.pdf
# 274 https://openreview.net/pdf/9a8eb48070ffcd0332fa35d7aaa9229cea1438c4.pdf
# 275 https://openreview.net/pdf/ca9300afa27a5e288f00410b0655430fc659992f.pdf
# 276 https://openreview.net/pdf/d063dd57873c6f1e3f057dce573f03f701ecfbc9.pdf
# 277 https://openreview.net/pdf/80b3c1437da640596290ef697263339b9b5b129a.pdf
# 278 https://openreview.net/pdf/1db8c4c76892b1cf404f833704cf1b8c3b12cbed.pdf
# 279 https://openreview.net/pdf/c586bb7922f76665c6cafd577bdef3f4b80b6830.pdf
# 280 https://openreview.net/pdf/3855d1c2cca291af2a3c7ff6f130f856aa972172.pdf
# 281 https://openreview.net/pdf/8e9825a8e9446ab79ae7406ff203d26aef5828ed.pdf
# 282 https://openreview.net/pdf/379e5b604e414a7c1631c5a2c50d091e6ecc7dd2.pdf
# 283 https://openreview.net/pdf/4ea3ad87a56cd6ae4ee25fc6bbbdd372ea7f6f93.pdf
# 284 https://openreview.net/pdf/2fc185e823ba9ba524ccda50e31b78c2b9c9d3fc.pdf
# 285 https://openreview.net/pdf/dda5a2906920f9b23fa0771810338e894628d79c.pdf
# 286 https://openreview.net/pdf/796796a029ced8802809466b46664cf779ac0a9e.pdf
# 287 https://openreview.net/pdf/598dcb22bf0b8bb14d3099e26976d5ba9bf3b3a3.pdf
# 288 https://openreview.net/pdf/69f475d9352b20ebc3fc03da590f54192f7856ec.pdf
# 289 https://openreview.net/pdf/1a374aff7de3e1aeead98c90aa71b476be6579c0.pdf
# 290 https://openreview.net/pdf/62d267bced5f7a24db1b239d5ee670b50f2776cd.pdf
# 291 https://openreview.net/pdf/f1fd07860b80238a145607a2cc1429011d414718.pdf
# 292 https://openreview.net/pdf/c862f73b59ac7901d308f37d0e938a9e4d7ddaf6.pdf
# 293 https://openreview.net/pdf/100ce9435fb820f433bb2a423491a43ed4f64862.pdf
# 294 https://openreview.net/pdf/1e9242b28d79ef54bf7b76112fbc461769488ec9.pdf
# 295 https://openreview.net/pdf/896805d4e8de1abe529f0fcfcfe247092bfdcdfa.pdf
# 296 https://openreview.net/pdf/fb9df9d03bb4d2e3e81cc9237baa589e56cc59d0.pdf
# 297 https://openreview.net/pdf/ce610a870c158fa2d00bbfd333e6881260c3ea6b.pdf
# 298 https://openreview.net/pdf/6a73e95053a44e33e96d38a7d3fc15c14bbe50d9.pdf
# 299 https://openreview.net/pdf/7d911db624dbef32307326a63245f3cbbda59142.pdf
# 300 https://openreview.net/pdf/73bf458dbe5259950ca0596d1ae7ed0b041f59eb.pdf
# 301 https://openreview.net/pdf/13c9218efd3a171ed6da7c92777b14f0d597a58e.pdf
# 302 https://openreview.net/pdf/5f94e0f4ee81b03843b4fc8db4dfb7bfc78dbfd2.pdf
# 303 https://openreview.net/pdf/04225040cdc5b044ca6f8a49e174e32a0bff4196.pdf
# 304 https://openreview.net/pdf/e6cfc858d7dfca232e84231fb4af2c1decd454a2.pdf
# 305 https://openreview.net/pdf/41a97d1a38e6c62bc037998a39c3201184ec1317.pdf
# 306 https://openreview.net/pdf/58468a45facccea4727809a26664270da375e8d8.pdf
# 307 https://openreview.net/pdf/1e453f0df117752fa75e7810ace4310c4099f97c.pdf
# 308 https://openreview.net/pdf/69faac947ab545cf16568ea7a205f86a264b43b5.pdf
# 309 https://openreview.net/pdf/d61e10a837c5f3f7e8fa7bd221a69f5872050984.pdf
# 310 https://openreview.net/pdf/6b1d947f2e3ef1d00d6505afa1d44a021202d5b6.pdf
# 311 https://openreview.net/pdf/0e06ac24a36ff9f5fd36ee26f34f9486c8b0a09d.pdf
# 312 https://openreview.net/pdf/a6de65e30a4f92db61abf0edf3d28244f2d18a6f.pdf
# 313 https://openreview.net/pdf/04f652450ee4706ff6565dc9df8580e1881050b2.pdf
# 314 https://openreview.net/pdf/fa60437d007be2312f49bfe0e1aebfab94534575.pdf
# 315 https://openreview.net/pdf/bb4750b65866d1d9d4d1088f8e0de8b60e3d554c.pdf
# 316 https://openreview.net/pdf/3b6a297e3a6c2f568ec5b521b172a207403e9f93.pdf
# 317 https://openreview.net/pdf/b64642f9ced9d99f97529b07fb5608d3f7f4aedb.pdf
# 318 https://openreview.net/pdf/cf2ba337d410809186cefd884234463af489a061.pdf
# 319 https://openreview.net/pdf/18c88c7f5e1e879a25bc80d387586cea8f118761.pdf
# 320 https://openreview.net/pdf/e7b48c662a15dbddc1a3d5c9a2b338c13189506e.pdf
# 321 https://openreview.net/pdf/792d0f553c3b9eb4af6aa81dea97790a1288f830.pdf
# 322 https://openreview.net/pdf/3cb060815b59f1f8386145f72e18502aa70cf415.pdf
# 323 https://openreview.net/pdf/bcce19ed68bdb0a34957207b9b69cebedeab384c.pdf
# 324 https://openreview.net/pdf/56f5b528ba9ae4f7c40ca328636fffe7c8c0c7da.pdf
# 325 https://openreview.net/pdf/7c2293712e38a0aac1d8fd3626056875cd130375.pdf
# 326 https://openreview.net/pdf/f6e1ffd51a2415a8b0d1b98c2fabdf7bc677dfeb.pdf
# 327 https://openreview.net/pdf/7f8a9a85c1c411df22a3dc2b13ba786a162396d2.pdf
# 328 https://openreview.net/pdf/bad3599bfddaf9f576a9c84fc0e1ddb678a2c5dc.pdf
# 329 https://openreview.net/pdf/b8975b72f550b7061f9e42248a7f29257a2c71fc.pdf
# 330 https://openreview.net/pdf/3d73c1e257eb3d1dd034f43fe3b51884a6dfade4.pdf
# 331 https://openreview.net/pdf/7835ef364a3e5f77397911e7f2f90b3aa3630f8b.pdf
# 332 https://openreview.net/pdf/81a9113f5d14dd8b4ef54bec29a755e76f29d71f.pdf
# 333 https://openreview.net/pdf/feb4b9be1c1d0679cf4c1f97725f3ae7e2e8d153.pdf
# 334 https://openreview.net/pdf/b3774a7e6b7bda0783528bf1dc8e2600707d797f.pdf
# 335 https://openreview.net/pdf/dafd4dbfa124993610ceda1a2409041764a1726c.pdf
# 336 https://openreview.net/pdf/75004a05d69f69c50fcb4744c1e451be4ecb0ed2.pdf
# 337 https://openreview.net/pdf/c053045ee07e0ab96c46d5962f198dcadb2b12a7.pdf
# 338 https://openreview.net/pdf/4fb00b07fe7fa835d884ba4dd5c3e2a169655329.pdf
# 339 https://openreview.net/pdf/5c337ba7d563872f1a5d203061c5984c0059509e.pdf
# 340 https://openreview.net/pdf/787489763506d1437ac7b05b15f89ea0beb8c3b1.pdf
# 341 https://openreview.net/pdf/8e7841af8eb252d92737a922f2185e0a11bcbb81.pdf
# 342 https://openreview.net/pdf/886cc923e40101cd74cec91aa5c918686d5a8dc9.pdf
# 343 https://openreview.net/pdf/f60b645e8df81d8ea0ffead31c07b375f9d0c667.pdf
# 344 https://openreview.net/pdf/67dcc1b0cfc87e5d6aeaf0391094380da9c1897b.pdf
# 345 https://openreview.net/pdf/078a57e9be24133bba8f13f809f74c4f77aedea5.pdf
# 346 https://openreview.net/pdf/07814e3fdf1a092fbe16856bc382b68d8260fb58.pdf
# 347 https://openreview.net/pdf/52b372086d6400939b04ee4282c4ff02351bb3df.pdf
# 348 https://openreview.net/pdf/10eb4d0b2c9232991827cc7d0ada38e1a727ff3b.pdf
# 349 https://openreview.net/pdf/6afcd9948e9a8f36dcac913dfe67d5311fc6c5df.pdf
# 350 https://openreview.net/pdf/bf1425a56dca436f66a704e37ad8495c1fffbd44.pdf
# 351 https://openreview.net/pdf/f38fe82f5899566cd7afbcc789af60cf3ce75aca.pdf
# 352 https://openreview.net/pdf/982a7ad6a22caf7e77aba86eae6cfd1395299bab.pdf
# 353 https://openreview.net/pdf/ebe8ec2526826ab8aca7189c0b3935036603f11c.pdf
# 354 https://openreview.net/pdf/34f8551e26fdb224d41a5e8d657806c13dc98cb1.pdf
# 355 https://openreview.net/pdf/9f93e0d4c655779a0d34fa9c6b44695db75d747f.pdf
# 356 https://openreview.net/pdf/73ebf3d9d08b88d3b59f24b690fe3f2584b6d628.pdf
# 357 https://openreview.net/pdf/c01c2ff2b48a04edc773df45808b90334aa74cbc.pdf
# 358 https://openreview.net/pdf/e347eac2b88b79fa33f30cc25bef52d52838183e.pdf
# 359 https://openreview.net/pdf/aecdf7f8281e50fbbedf1b0bdb5bc5401421aa7b.pdf
# 360 https://openreview.net/pdf/9108500ac8fc26edf6db34495a32ebed80b1b752.pdf
# 361 https://openreview.net/pdf/c7d957d8284e509ebcc843292bf9d0d2902b8713.pdf
# 362 https://openreview.net/pdf/acf07a393261c288a91ec34bfc2e861effdf9587.pdf
# 363 https://openreview.net/pdf/7fe5e732a2941dd03e2c177e713426dde3d324a2.pdf
# 364 https://openreview.net/pdf/123b8a992a9e420ee592c1f8b175c9a439aa2f58.pdf
# 365 https://openreview.net/pdf/460ec25606f882a29517d930276f1c06d2f978a1.pdf
# 366 https://openreview.net/pdf/8051d7378908632625fe596b7ef05390f9f2b32b.pdf
# 367 https://openreview.net/pdf/a026a8cbc58742361cbc7a85b6b6e34230b538f6.pdf
# 368 https://openreview.net/pdf/f79b3ac494d465f44557e3e5b9f6d460668b91fc.pdf
# 369 https://openreview.net/pdf/c9c64a5b7d6d1b3b977f973ab553b08580576420.pdf
# 370 https://openreview.net/pdf/bc66a3bbb804a7158ba77a4de9f91a196e8eaf9a.pdf
# 371 https://openreview.net/pdf/5d536b4991d001b1cb1a44b7b6d5785c2f3012d8.pdf
# 372 https://openreview.net/pdf/5fd307801a722f24990855f8235ae461cabf66fa.pdf
# 373 https://openreview.net/pdf/bffcee09d1939996b54123724697afa1a9d4df37.pdf
# 374 https://openreview.net/pdf/530069ca95ee1f18f6294d9c9a95d0cf08be40a5.pdf
# 375 https://openreview.net/pdf/c0175c563fa075f176f82b1076b55b07f12c1443.pdf
# 376 https://openreview.net/pdf/ade16b484acbf893d68b474e358135e8d62075bc.pdf
# 377 https://openreview.net/pdf/eafc4c90095ecd7ec1564dc307b7c03395530b1f.pdf
# 378 https://openreview.net/pdf/1b61af1a33431698535cc04db8211357bbb1c816.pdf
# 379 https://openreview.net/pdf/8fcf77a080574ee36abb6525663524292f7b5217.pdf
# 380 https://openreview.net/pdf/3b00d0d74db7a433bc3538ced7c57c5abb5c2bb9.pdf
# 381 https://openreview.net/pdf/28f4471b307550d3ccc1dd10e23ed088114a0109.pdf
# 382 https://openreview.net/pdf/ed95c4bcd6adab13afbd8b1e4a103183ce45bb04.pdf
# 383 https://openreview.net/pdf/b48d4f49696c822ea5644e2ba131c474e0f8c770.pdf
# 384 https://openreview.net/pdf/11ef7dddb6afa574c5155ad2ab939d2003119399.pdf
# 385 https://openreview.net/pdf/57f1f7a0ace4393206d443c0b6802a84b7996678.pdf
# 386 https://openreview.net/pdf/4ee95daea73cb05d2ea8780258b25684ccd82a88.pdf
# 387 https://openreview.net/pdf/cbdf54e075523d503dc1b31538bc70e029256b15.pdf
# 388 https://openreview.net/pdf/43a223366895717baedd64cdaf18721f669b8b0a.pdf
# 389 https://openreview.net/pdf/3a0f22bd7748e3a5e79b5973a182c5777b2aab02.pdf
# 390 https://openreview.net/pdf/c64fff33e353b59b290ce474751703a04320e805.pdf
# 391 https://openreview.net/pdf/29b7a937e4233d944f06cc530414bef7be4d941b.pdf
# 392 https://openreview.net/pdf/d1dc0cd88dd5ccbe6f490f777bf4b3c297639f36.pdf
# 393 https://openreview.net/pdf/20b12822064b2d7eb054021a0f1209e1dd066515.pdf
# 394 https://openreview.net/pdf/f6e0ef2be0578f171a67040f6fc6873a70f1ac9c.pdf
# 395 https://openreview.net/pdf/ee29b6c12ae1ba4cc06f1344b66ddedd58ca385c.pdf
# 396 https://openreview.net/pdf/fa3c83b8ced74fdc2103d3de7774170ced113e61.pdf
# 397 https://openreview.net/pdf/6fc3f1f47cfa05419880ffa6cda79c7d606c80ed.pdf
# 398 https://openreview.net/pdf/74dd084c903745b8d7a05481d46ce0275b077c6e.pdf
# 399 https://openreview.net/pdf/8fecedc380fae9d1025815dc9e8f0bdac4616474.pdf
# 400 https://openreview.net/pdf/6c5f6f13f280ac8c82127dd17be8dbd18d697702.pdf
# 401 https://openreview.net/pdf/c06884cb07438f1f31c60d5151e54b39e26d33d4.pdf
# 402 https://openreview.net/pdf/49232cd55923175bab0a33ca81d281c76edcfaad.pdf
# 403 https://openreview.net/pdf/4cafe28b1dd5a7c27cf01f45214e4fc6fa3754ef.pdf
# 404 https://openreview.net/pdf/acec0f5ae7516ca813b54adb61eef2b9726b4559.pdf
# 405 https://openreview.net/pdf/9b1abc99da7f78ec360a4288ad20cecabb1eed6a.pdf
# 406 https://openreview.net/pdf/515b0ec07db7d7e603d68eda09eb8978669607f4.pdf
# 407 https://openreview.net/pdf/4a6997b8721473954b4dad5139d7b6ba92161a7a.pdf
# 408 https://openreview.net/pdf/5bb259d4fc89a118041f31e8405c7ab23df0b4a7.pdf
# 409 https://openreview.net/pdf/bc40b11773f87e44c9cbaad664670bd51ad5bf49.pdf
# 410 https://openreview.net/pdf/b894a2207c27ab7dbfa757457e0d564961e16304.pdf
# 411 https://openreview.net/pdf/0d99596c95cb4d3a55261e2f678c7d9379ebd941.pdf
# 412 https://openreview.net/pdf/eec9f35dfb2a2cd0ffec4b6c7bf3eb7b59674819.pdf
# 413 https://openreview.net/pdf/80b15bdf5559f1ef0a9d7e925b87d086f68cb300.pdf
# 414 https://openreview.net/pdf/e2b7f14c4eb028489005f8a3fcd76cda587a48b4.pdf
# 415 https://openreview.net/pdf/99a6274fc82db36d3d97dac70aa2eefee7af43fc.pdf
# 416 https://openreview.net/pdf/36e73dd04f8cde5d1e7e60fd900922f0323d4a2d.pdf
# 417 https://openreview.net/pdf/0ed7119196bfabbdc248d6add738ac67510f7662.pdf
# 418 https://openreview.net/pdf/59c43d042cb8f78f451c2448d1e264cac3e59e55.pdf
# 419 https://openreview.net/pdf/25bebcfe147e7e7eecd28e707c7704dbd5cbd5f0.pdf
# 420 https://openreview.net/pdf/673240bc98b1eae3fb77e8273d3a69ca1c63f991.pdf
# 421 https://openreview.net/pdf/07f52b0cfcfa78cc82a16e6bcc38e315ca2d88eb.pdf
# 422 https://openreview.net/pdf/0e4abd1f6eb3aaf0f63fe644beb5b3d81bd3c2ab.pdf
# 423 https://openreview.net/pdf/ad19dc82b73d87a8e38ef475dc72f82e75ea328e.pdf
# 424 https://openreview.net/pdf/62bcdd1a9ae7d7eed9077d4611f537d21827ba33.pdf
# 425 https://openreview.net/pdf/e99034416acd1ca82991f5d63735e77130fc06a7.pdf
# 426 https://openreview.net/pdf/c28b221c8c849bf17d74b8eea6ea662ca5d48596.pdf
# 427 https://openreview.net/pdf/abe676c41d571977f05ff1eee049ec4fb86d0301.pdf
# 428 https://openreview.net/pdf/6dca640907739533f2dc7a6e7b7d2e4104fdfc43.pdf
# 429 https://openreview.net/pdf/cff0f7a1456deb897c74f850843d402984e25dee.pdf
# 430 https://openreview.net/pdf/d0d0d22aae068ed7435e41a81b5c64e65c45de0e.pdf
# 431 https://openreview.net/pdf/9eb659a9e4eab9fae289c8a5d9746a06d028fb30.pdf
# 432 https://openreview.net/pdf/faeab4d09992879ea2975e162007c18ebc32b833.pdf
# 433 https://openreview.net/pdf/4772514cf5bd39016c62e2466d66a885ec04abb0.pdf
# 434 https://openreview.net/pdf/82e26746157162c31320d9c1dfb8416ee127cb6e.pdf
# 435 https://openreview.net/pdf/d59b24dc62f96828d592ff6b7f4251f3516e72b4.pdf
# 436 https://openreview.net/pdf/e4ea10108dbde640764dcde0449ba8a267d56786.pdf
# 437 https://openreview.net/pdf/1d2c639ef2854b3b11b68b4617d0ff967b6b54ee.pdf
# 438 https://openreview.net/pdf/81fc7c68487b51f4cf252f7eaa1571f38b45e4cb.pdf
# 439 https://openreview.net/pdf/049f5107e077d13a5ae7171b7db96ad93ed5f23c.pdf
# 440 https://openreview.net/pdf/444a2eefa1d302c6578e50b28a266f21a0f2dd78.pdf
# 441 https://openreview.net/pdf/bc80a9227fea49be8184c7c7b8337a59e740d921.pdf
# 442 https://openreview.net/pdf/01e9da5b9f2f14634d2c20dc0ea7ec93f766f1e1.pdf
# 443 https://openreview.net/pdf/11def978889827cebd99ce8e154f1d7a8ba62dde.pdf
# 444 https://openreview.net/pdf/7d000edac11267f0b5a613d835780cd4ccb9102d.pdf
# 445 https://openreview.net/pdf/48b3d62fa0cacd2579c8fe3196c54df1c124b713.pdf
# 446 https://openreview.net/pdf/ac84301d264f93b0bad7fc13e9ccec37b4c161c4.pdf
# 447 https://openreview.net/pdf/e2a1d8064ef92b75c5a2601cf5660a43e0a3c2b5.pdf
# 448 https://openreview.net/pdf/a97a7f9982819e0f3d958c7e66e3f208e5ed1f0a.pdf
# 449 https://openreview.net/pdf/edfe9a9790acaf48cfdf2cef54e56e5415de1ce9.pdf
# 450 https://openreview.net/pdf/df55da2e989573994cb4ae1f0980edf76c5eda64.pdf
# 451 https://openreview.net/pdf/91155c1d20ebb2459f323d4c79bd7d7443538244.pdf
# 452 https://openreview.net/pdf/1b9dc2a64981e1aed8cd26cf42fd80d4a85952d1.pdf
# 453 https://openreview.net/pdf/98601f415eedff1073917a2b7eeacd6ce9a0031f.pdf
# 454 https://openreview.net/pdf/a956f4e4759ae722c095dbea6bc4a342ff06edb5.pdf
# 455 https://openreview.net/pdf/e6af691c8b99ded8ac36a84a1c414c675fb32524.pdf
# 456 https://openreview.net/pdf/b555725c914e1f9fb64a37dce8fe336643c34b60.pdf
# 457 https://openreview.net/pdf/273dcb84008aa40f2e4242665024b0530d6726f9.pdf
# 458 https://openreview.net/pdf/42de109f414e67f76460868cbe626f2883ef913e.pdf
# 459 https://openreview.net/pdf/09f15f099bff7462f2de83c31dc94188919b6b4a.pdf
# 460 https://openreview.net/pdf/f6e0700b1a4de32f13aabefaa7a865a60b7ce2f2.pdf
# 461 https://openreview.net/pdf/d57a9451a08466721ee7491fba1d3dc9d43885d5.pdf
# 462 https://openreview.net/pdf/da5e8f08d3b77ad1fa09f2cdbfb98eeeb8ad0be2.pdf
# 463 https://openreview.net/pdf/5cc536524468ae2c835ff418fb451e9cd89a144b.pdf
# 464 https://openreview.net/pdf/f1381864a204bd72893edb2f68b6a7fde64a591e.pdf
# 465 https://openreview.net/pdf/a9b5c1cac35cce14dad1036f5b0f324ad899d11f.pdf
# 466 https://openreview.net/pdf/ee043d338b4d99fee86cf7332af005a6da63696f.pdf
# 467 https://openreview.net/pdf/3f955a8cf103d552d11f9329dde46d6173f574aa.pdf
# 468 https://openreview.net/pdf/aa51f28767b5d95ceced7af0c79780b06d2fd1e0.pdf
# 469 https://openreview.net/pdf/c424f659741e75523481d13c0571a72810a748e7.pdf
# 470 https://openreview.net/pdf/a2c365918c8b9f3e5b7cd871606f05d90118525a.pdf
# 471 https://openreview.net/pdf/c894feb463ed37d5cc8d162cc536ef32cec703a4.pdf
# 472 https://openreview.net/pdf/ed35cc59666dab7baf7735f5b066cdda25ff209c.pdf
# 473 https://openreview.net/pdf/93690cedc98df54d9436cdba00f2f05f6feb14c4.pdf
# 474 https://openreview.net/pdf/2d65b8c77aa847a85c9b2c52cdc40da5cb29f7f3.pdf
# 475 https://openreview.net/pdf/aeee21470192eaa2586e8e5753e1786422f0a4a4.pdf
# 476 https://openreview.net/pdf/a85720226519d67aa19c355249659426e1a803e5.pdf
# 477 https://openreview.net/pdf/2fb6806a7944ccfc8c512bcb53fd1b093b7abb59.pdf
# 478 https://openreview.net/pdf/d327bf02bd2a0d504c67bef799740c5066a22440.pdf
# 479 https://openreview.net/pdf/2e3473dbdda28296a3768b5ed5b6c5e32a9a53de.pdf
# 480 https://openreview.net/pdf/032565002e39f747d69e618dba2713aea4a88f39.pdf
# 481 https://openreview.net/pdf/79a0f9b78ef87a8465c2f60eac8f96b996c84b38.pdf
# 482 https://openreview.net/pdf/6898c82c5b21db80852946fd9654eb732b14da89.pdf
# 483 https://openreview.net/pdf/9f75235bc383f592ff6dce2f44b927b805abc762.pdf
# 484 https://openreview.net/pdf/659883ef372c8360527a91f5fd9b7096a95b71d2.pdf
# 485 https://openreview.net/pdf/402c531d6593a053e759e45ba18de2f2cc84dd23.pdf
# 486 https://openreview.net/pdf/f3ca1fa9d17f49965907475ddd7aec866f2bcf17.pdf
# 487 https://openreview.net/pdf/5133e05de4997ce07895732d586909263b656b92.pdf
# 488 https://openreview.net/pdf/e3b883e017b0851028dcb0d46a259085e75954a2.pdf
# 489 https://openreview.net/pdf/1296bdb5a4584df2d211f20071d2a27ed06b4e47.pdf
# 490 https://openreview.net/pdf/c35dec93c98d1cbcaa6f5b89ee16b1bf20203b19.pdf
# 491 https://openreview.net/pdf/fdb302140f3d4345b9a8529ccdf5a33ee5e47bd6.pdf
# 492 https://openreview.net/pdf/f1b028aa4625f6bba529769c5861a2918585a87e.pdf
# 493 https://openreview.net/pdf/bc30667c89961e244c8b6d8dd71c2e9dd4e9accf.pdf
# 494 https://openreview.net/pdf/038dfa02f4db91727a62f21366ad7dfe0db07dbc.pdf
# 495 https://openreview.net/pdf/4919425fc00a999aa99ff64ba1e275ca945e9f6f.pdf
# 496 https://openreview.net/pdf/45814608674a65be9aad3ce633d9134f54eec28e.pdf
# 497 https://openreview.net/pdf/313cf89cc88e2246fb00c5ee369cd4f9170c30d9.pdf
# 498 https://openreview.net/pdf/32f905f7b59d8387d786164f86e62a4c3293b481.pdf
# 499 https://openreview.net/pdf/ddc06a1dba96714dc462fb36685cd562658c9d62.pdf
# 500 https://openreview.net/pdf/e0eb53dc5e71f1337dac893a905dadd32813389d.pdf
# 501 https://openreview.net/pdf/efce74618927c1b658562643f202ee2c472d2056.pdf
# 502 https://openreview.net/pdf/35f3e94fd4c6765836d89bf0ee8307a99020a02c.pdf
# 503 https://openreview.net/pdf/fe25cc93fd8be1315c9dddc19556db59058e3e47.pdf
# 504 https://openreview.net/pdf/a6ee04305991a9efa073850bebbec9317ac4de6d.pdf
# 505 https://openreview.net/pdf/696171827b35dfe4e639dfe0644bf0f279f84c75.pdf
# 506 https://openreview.net/pdf/2cfdf569529c2c31505b56782cfe6ccfe97b5e49.pdf
# 507 https://openreview.net/pdf/61a9997b3387f47e7b966c74be0d6e4b70d4c6dd.pdf
# 508 https://openreview.net/pdf/77b2b9320e912b9c57129834fe4eafdfeaf9399f.pdf
# 509 https://openreview.net/pdf/2213116e2bc69d245d15ec4f4ff82d2de202dbe1.pdf
# 510 https://openreview.net/pdf/759017e171fccb1d81f8a521cd4babf7b0d0c16b.pdf
# 511 https://openreview.net/pdf/4a0637d97e03d3ced4f839174d866a19d66d54e3.pdf
# 512 https://openreview.net/pdf/8b9428278fecebbf54dd7baa215439f4ffb8f5f8.pdf
# 513 https://openreview.net/pdf/c5b5942dcebdadd33ffb658b204ce20b1205419f.pdf
# 514 https://openreview.net/pdf/f99f2d5ea7fda817912034e810f9e385d2add0e1.pdf
# 515 https://openreview.net/pdf/78403b3ae7bbdc9e73614cc0b261982b15a6a1f0.pdf
# 516 https://openreview.net/pdf/1268f4a67e362911d65e2a20d7838b6c7a80f1fd.pdf
# 517 https://openreview.net/pdf/6501e6eba39a116305b247c3726769e527edd8a6.pdf
# 518 https://openreview.net/pdf/72fa2584e48da1dbaf83591557d3cdc6111c9160.pdf
# 519 https://openreview.net/pdf/0d0633049838da07b4f5de064de1fbac697d92c3.pdf
# 520 https://openreview.net/pdf/99ca2c2c7fad648ba8228303adcadc43f51085f8.pdf
# 521 https://openreview.net/pdf/6570cf14640b106571e1d2ce08ee384f1f17eeaf.pdf
# 522 https://openreview.net/pdf/960ab88f57531b40e2fb8ef0c415c93bde9c93f4.pdf
# 523 https://openreview.net/pdf/de359ab88345f813772416a324f7c4dc07f7eb40.pdf
# 524 https://openreview.net/pdf/34794ce7f5bc7c768a763b81bd3758466fc01e8b.pdf
# 525 https://openreview.net/pdf/4d8650f36612053fb6f48b9d246f2fa62c8c1a70.pdf
# 526 https://openreview.net/pdf/a0002e329d4a358d2fa21a2a24095d9ef78f509a.pdf
# 527 https://openreview.net/pdf/6221a95d8c43a6ddd2fa681dcbe6bd16a99cc4a1.pdf
# 528 https://openreview.net/pdf/0325b58a2ac2724964902acc4364ed6643a4503d.pdf
# 529 https://openreview.net/pdf/7583f82341c0cfc0b1cd55eee0efeb803b8b442d.pdf
# 530 https://openreview.net/pdf/436aaf32e1b486629ded2a43e9948561a33e4882.pdf
# 531 https://openreview.net/pdf/e73172f359a19430928855ff049b5dd1e7a4d987.pdf
# 532 https://openreview.net/pdf/5124e3ed078b69949b650fc3e97fcc328fafe4ff.pdf
# 533 https://openreview.net/pdf/36cdcef566ad431e1ed53bed1c6ffee73624b56e.pdf
# 534 https://openreview.net/pdf/604897aef15b079d51c54327714b9097f3fd1c77.pdf
# 535 https://openreview.net/pdf/f216a90079436d1252e5157ce9e925639303e624.pdf
# 536 https://openreview.net/pdf/add1bea91fa94adb7878a8aea09779013996f6f2.pdf
# 537 https://openreview.net/pdf/fdc050beb1912f712961755736bfa6e97c3ad7ed.pdf
# 538 https://openreview.net/pdf/2c02a5591edf314716fb0835c0bbf39ed7f16f4e.pdf
# 539 https://openreview.net/pdf/b0f398213087ced361c7136cd33800f94b074f47.pdf
# 540 https://openreview.net/pdf/26d97b558e9960e54d01be17e3b8f016a2e1a5b1.pdf
# 541 https://openreview.net/pdf/f89504e5bbcc49fa0a071aae9a9e0a2d2c17d5af.pdf
# 542 https://openreview.net/pdf/7c26399c945d00b48314c114168dead210a296bb.pdf
# 543 https://openreview.net/pdf/0d646a41734ec2da7b7e2152f5955a8d30a0fa16.pdf
# 544 https://openreview.net/pdf/12d1e22292ed56512748543827e4cf87c98d1534.pdf
# 545 https://openreview.net/pdf/f95b8bee808d335bb430ec2c78a939cb49d8409e.pdf
# 546 https://openreview.net/pdf/49d6b86ab0e7e462cb8c8ce80e8aea6faad45cd7.pdf
# 547 https://openreview.net/pdf/4e056f415188ed58053ecc69d8168e2e3af4699f.pdf
# 548 https://openreview.net/pdf/3c2e3aeb186222debad25556ebcac44d6fefceae.pdf
# 549 https://openreview.net/pdf/4f2a83999ae673e42f124c6156af1846024558cd.pdf
# 550 https://openreview.net/pdf/ef1c228d5dfb50d53274fce451f1a38f3733cf04.pdf
# 551 https://openreview.net/pdf/49efda6feccac495256971139ea3c45e985d5e47.pdf
# 552 https://openreview.net/pdf/e3084ec2f74740b38898088ef2612dc8f24c4679.pdf
# 553 https://openreview.net/pdf/a31a5689fb60b879c4c916ee38397855e69d77bf.pdf
# 554 https://openreview.net/pdf/7cc08c44de490f3e79794b5827aa36b84f99c4c3.pdf
# 555 https://openreview.net/pdf/692b01680e7fd5f063d8b26e23d90632c95bfe54.pdf
# 556 https://openreview.net/pdf/0d3d59b67588164a2bfd3758de67d8e3ac0836ae.pdf
# 557 https://openreview.net/pdf/35291cb62b7adecca2b366ea7974108c795ee5fe.pdf
# 558 https://openreview.net/pdf/171649778505c4657d0104b10a76985a2a07e353.pdf
# 559 https://openreview.net/pdf/ed239cc1ef00f8d1c45bc610a589a7336cd17a03.pdf
# 560 https://openreview.net/pdf/c9986237d38c28a57afca986158899ccc24608c4.pdf
# 561 https://openreview.net/pdf/69a93ee485937f20ef8e038175d50d6230e3fab4.pdf
# 562 https://openreview.net/pdf/83be469cfb05989fdaa09e9ae079b8dd86eecccc.pdf
# 563 https://openreview.net/pdf/e62b9fd3b63639f57c669991b7ad9f9b89065016.pdf
# 564 https://openreview.net/pdf/94ca83ca26f12af239d4912c51044a7e9118fc82.pdf
# 565 https://openreview.net/pdf/0525b7c34858f8b6ee4e0daf392fbac3bafd934a.pdf
# 566 https://openreview.net/pdf/b2afc63256282993f5c85e5494645b2f7679dd58.pdf
# 567 https://openreview.net/pdf/a92bfd1104557dde36cb8e76c175d280b76513fa.pdf
# 568 https://openreview.net/pdf/f5fd141e43c05b949250d117196dd2093ef787b5.pdf
# 569 https://openreview.net/pdf/768d155c1f9dc5850d4f0168d19575e8c747490e.pdf
# 570 https://openreview.net/pdf/eb8531535f3c119950bdf295af5b855bb6efde39.pdf
# 571 https://openreview.net/pdf/8fc126a1a620c64311843662c1d638848bafea07.pdf
# 572 https://openreview.net/pdf/2d3ef5812dccf804b4de18d9cc5fb5cc98d3ba9a.pdf
# 573 https://openreview.net/pdf/7ea45a979586553655c6c9eedc0decdb777aaf1e.pdf
# 574 https://openreview.net/pdf/47408bc9577d0861019503ba5d9335fd4f64c01e.pdf
# 575 https://openreview.net/pdf/e912a44f0918afb75e3814a49642d5a177abcd52.pdf
# 576 https://openreview.net/pdf/52af7225d7de609b61840c7cb0d899b963a2013e.pdf
# 577 https://openreview.net/pdf/5355b9a9bc1eabd198a78654d7dbfa4e5f1664b0.pdf
# 578 https://openreview.net/pdf/82a8b07b92c2fbdc0b7a66513a35f49417f7074d.pdf
# 579 https://openreview.net/pdf/e753531653e14a7dcf17c5464773a7513e18f9e5.pdf
# 580 https://openreview.net/pdf/1681ebc739b289342749bf980f0b4bbe99acc50e.pdf
# 581 https://openreview.net/pdf/e129ac7ac66f9fbb8997557423dfd3fe9e4ca72c.pdf
# 582 https://openreview.net/pdf/7a5e2aeccac1ea354d122a24d739db89c51f2599.pdf
# 583 https://openreview.net/pdf/e5a910f2f057d756e39a11ae53c4ea826433fa6f.pdf
# 584 https://openreview.net/pdf/8a73947300f12ce783d0fc9d13894271b7551b2c.pdf
# 585 https://openreview.net/pdf/409d076ce5528382d9695b832fdb2bebf4977300.pdf
# 586 https://openreview.net/pdf/9ec45170b27208411c953200b33d953c8bf25774.pdf
# 587 https://openreview.net/pdf/e19dee281e43ab70ef8f8640d6ccb689bed45bd8.pdf
# 588 https://openreview.net/pdf/1234255940e50d089d63ed177185c3ca2a32bd39.pdf
# 589 https://openreview.net/pdf/d1b5c296ac9bf1fd5add23936a6a867caf241799.pdf
# 590 https://openreview.net/pdf/35d098045a1896058e0813e94ff5730165c03247.pdf
# 591 https://openreview.net/pdf/7baf4a44b22ee9059ca564133650828b1290566e.pdf
# 592 https://openreview.net/pdf/871b8a661c3de03ebac23389dedd92af1f741b4c.pdf
# 593 https://openreview.net/pdf/dbd2c001478b511324bdbec3a393c6f1552fbb3d.pdf
# 594 https://openreview.net/pdf/22143e65729a6950f65c1f05020b2dca91f0aa53.pdf
# 595 https://openreview.net/pdf/7a989e6ade4320f5c727f1c39c23d7e6ad7cd1d4.pdf
# 596 https://openreview.net/pdf/b95e6782b7fb5d85e41e2eae52f99947c3d1acac.pdf
# 597 https://openreview.net/pdf/80e410381bef782f58972f74ca630e130d7b0bd8.pdf
# 598 https://openreview.net/pdf/2d4a5acdba73b6a9da35ef154d283aa0408d8077.pdf
# 599 https://openreview.net/pdf/44f6a3958bfee5b8302b55dd30335b9c8be982eb.pdf
# 600 https://openreview.net/pdf/5df524ab6c49a306d1f093cfd3d0b7c0264d6904.pdf
# 601 https://openreview.net/pdf/b0fa96363433b3be88301b7112890dd0988e1763.pdf
# 602 https://openreview.net/pdf/2216db2b926f80ad83932fad5ebbd912d8d3c584.pdf
# 603 https://openreview.net/pdf/c592033920ff62f8a918571339844556ea7ffb43.pdf
# 604 https://openreview.net/pdf/893cd27f203e1c4d6cd462eea1596210361ea469.pdf
# 605 https://openreview.net/pdf/2d0bee07a9f373073524d04d2dae5fab301d34be.pdf
# 606 https://openreview.net/pdf/b2c8d8ffd230a816fdb5106370cd0dc65865737b.pdf
# 607 https://openreview.net/pdf/650e8b5c38872cf721fff2c0b10c3e5fa039579b.pdf
# 608 https://openreview.net/pdf/b36dc0f3f80cd19f7198d10e37c8003772a84b06.pdf
# 609 https://openreview.net/pdf/d4dea9af12d57bd58abf72c6c2c9d76013bed435.pdf
# 610 https://openreview.net/pdf/4e562815d04d317b333187042cba4848f529de4d.pdf
# 611 https://openreview.net/pdf/2149ce931dc3c08d49e509f4db34a7730b8b9fcb.pdf
# 612 https://openreview.net/pdf/8a90aaabfc83b6bbb06e9e18b8e9657a7615415d.pdf
# 613 https://openreview.net/pdf/989f4c93e3c9b7bc38369560e925cdfc8ce7b1ed.pdf
# 614 https://openreview.net/pdf/611321d408406241366d080faa3da40f3aaf0098.pdf
# 615 https://openreview.net/pdf/f0a7c2996eab5d56791cb5d7feebe23aa9ca27c4.pdf
# 616 https://openreview.net/pdf/6e754faf7f089ebe1dee846c0fad6a7d4acc1215.pdf
# 617 https://openreview.net/pdf/bd76298327954855dea995fc6d01b6ef1cb2afed.pdf
# 618 https://openreview.net/pdf/7c31c0a62a504da99d44ae760203128b7080b729.pdf
# 619 https://openreview.net/pdf/db4880381e5ca7a65fa5ae7f37e99287c8978e9d.pdf
# 620 https://openreview.net/pdf/cb491b60a5f8ce9f7ff3728545e36117e39d8fbb.pdf
# 621 https://openreview.net/pdf/00a236907b21d7118010fb705f96b4a934acff26.pdf
# 622 https://openreview.net/pdf/1bf27b66e1ac5124b7cf6726e833f2902ebec00d.pdf
# 623 https://openreview.net/pdf/066a8bbdf9a4c5d46cca6f988e4e83de5ee753cf.pdf
# 624 https://openreview.net/pdf/0a992b36167d39752c459212325882e0c62c458e.pdf
# 625 https://openreview.net/pdf/466b989b957884cf930095f390668d105d4972ea.pdf
# 626 https://openreview.net/pdf/cfd03f19d20263d9c1d1cc026a2b3528392fc857.pdf
# 627 https://openreview.net/pdf/9ce1c16c5ecb90ff5b8ff8cf01d769360755f9e5.pdf
# 628 https://openreview.net/pdf/c938315f41ad379588ffadbc38372c32e2fc50d6.pdf
# 629 https://openreview.net/pdf/7cfe2acbce31598f117484e02c5acfb4e6bd0c8c.pdf
# 630 https://openreview.net/pdf/38ae9a6d49f8c8de73c63c07dd1bb214b1e1d1e0.pdf
# 631 https://openreview.net/pdf/5cab9457b013d537fb818c57e3ac00c817524faa.pdf
# ...
# 1793 https://openreview.net/pdf/1e6fe20a361c84b33e3e3353ddb7fade813947f3.pdf
# 1794 https://openreview.net/pdf/520bdf66a9155c04855905babaead2b9aeba0b5d.pdf
# 1795 https://openreview.net/pdf/2373c5be78206dafd9ec29428315ae3dd0483a2f.pdf
# 1796 https://openreview.net/pdf/1bfa8404268d943f9b45e7a4facde4ddef7259ee.pdf
# 1797 https://openreview.net/pdf/4d89566649ca26b4992a3fab78d893feb9ca8dc1.pdf
# 1798 https://openreview.net/pdf/8eeb662e01315fcdeccb79b7f1631b46d561813e.pdf
# 1799 https://openreview.net/pdf/9e908f41124f68da1eee1e02b61eb0fe1a2bffd3.pdf
# 1800 https://openreview.net/pdf/e4bd83cbf4ad64afe2edb5356e4800dbfc07072a.pdf
# 1801 https://openreview.net/pdf/4a2fc7004aba4e300882177fbb6f25b5a853306a.pdf
# 1802 https://openreview.net/pdf/b38ef477c7170fbb93d3cc004ca6860e5537faa9.pdf
# 1803 https://openreview.net/pdf/e5927dd1ff7287d972c5b409d85506a0c1b5825f.pdf
# 1804 https://openreview.net/pdf/dd230e9938db73b0fff7ee629cb682af034688fc.pdf
# 1805 https://openreview.net/pdf/9c51657e9bfcdd3af718352ec52673de11fec1a4.pdf
# 1806 https://openreview.net/pdf/88532cb9e4e51a0a4895559c78377e45c02e5d10.pdf
# 1807 https://openreview.net/pdf/0a1d74a2869a508a120fb5bbbcfdb6c83ec5a2df.pdf
# 1808 https://openreview.net/pdf/a6a37744cc523cf48502857a618469a713fa7d80.pdf
# 1809 https://openreview.net/pdf/ac99bda46ad5341e2d84ebc649bcc39f7c0c2c9d.pdf
# 1810 https://openreview.net/pdf/18168e52a8e41dd00675e86673642b5846e7fe3e.pdf
# 1811 https://openreview.net/pdf/ab0104788311808f8c526bb4a5471ed9eb68e476.pdf
# 1812 https://openreview.net/pdf/343010151ed9fac35ccacb9af20a1a02dff80be2.pdf
# 1813 https://openreview.net/pdf/ea60565f7f50777889e3d7d4e95d5feb7f8df5cb.pdf
# 1814 https://openreview.net/pdf/f56775cb4a11a46694f46c130d8bb184ef420886.pdf
# 1815 https://openreview.net/pdf/ecdd355b92a5c94223c83d89f392bd2a2f4e95c3.pdf
# 1816 https://openreview.net/pdf/c3e8cba227b3a22d13289e0a0427cf1e1e8c585e.pdf
# 1817 https://openreview.net/pdf/aafe80ddd42b86af7456921e5c0adac5ee814e7c.pdf
# 1818 https://openreview.net/pdf/28968ae7fa07510ed3a4c526367db53e51ef3115.pdf
# 1819 https://openreview.net/pdf/0bcbfa22875adf615372a04dc0242e01763e53ab.pdf
# 1820 https://openreview.net/pdf/31f018dbf1b4f56acf88d2715ebd70a6d3908c99.pdf
# 1821 https://openreview.net/pdf/36c115dd350b35beffcf18cbfd0a6afd2ab5a0e7.pdf
# 1822 https://openreview.net/pdf/304a7da98b79c8c15e8baa9f038951976a9ef764.pdf
# 1823 https://openreview.net/pdf/f98704c521e5df54883c99e029e7e14b042f444b.pdf
# 1824 https://openreview.net/pdf/6ff14d56f7dc40f18c89e2f662622ac68aef3081.pdf
# 1825 https://openreview.net/pdf/65504b4ddfce51504320874a061bd0ea2e9bf146.pdf
# 1826 https://openreview.net/pdf/e48a9a4f65b3e90e5eb68d7d40919f152896d463.pdf
# 1827 https://openreview.net/pdf/b65a5392645765469baab2e39bb691bf22a9e6fd.pdf
# 1828 https://openreview.net/pdf/59d490c9944a87d96bea36cd12136115535559d0.pdf
# 1829 https://openreview.net/pdf/dfb67a3133a5a3472f5d247fb660e7370c9627dd.pdf
# 1830 https://openreview.net/pdf/fbd330b31dd69cf244b53291887b18ab9c2989b8.pdf
# 1831 https://openreview.net/pdf/d344e51366b6eeb1347bf96857a1cdeb5ca03e64.pdf
# 1832 https://openreview.net/pdf/cbfb25ddd5cc474e8abe2c6d9743deeda0893b4a.pdf
# 1833 https://openreview.net/pdf/496745066b9c086ce2dd3194dcc4f0147bc957e0.pdf
# 1834 https://openreview.net/pdf/c736a5eb1b3725f9b4f33606a1b8d964c4cbd9e8.pdf
# 1835 https://openreview.net/pdf/3396bdad57ddfcaa446c4c0d7dc44f99e6f6f3d8.pdf
# 1836 https://openreview.net/pdf/c01f6658c7826cbcf5c1890245476488b0e8051d.pdf
# 1837 https://openreview.net/pdf/3c3da633058982171bc01205d90d6dbeea96b163.pdf
# 1838 https://openreview.net/pdf/a357c2785026e23479c5fab30ac3cfbe3b3cd378.pdf
# 1839 https://openreview.net/pdf/20a87eb23a2421db12fece55b995dcd0b8d4dfe7.pdf
# 1840 https://openreview.net/pdf/9374f8281e7fdf83eea919810912cdffa49f48a2.pdf
# 1841 https://openreview.net/pdf/606fb09bd84f729bc308ee0e859bca508d2d5c14.pdf
# 1842 https://openreview.net/pdf/8ab13ab21294b253f6383e9f4bd2721cf210f75f.pdf
# 1843 https://openreview.net/pdf/01caf3dd0ea1be0ef1782bbb1dbc2a81569dfb0d.pdf
# 1844 https://openreview.net/pdf/be7956b2e543e1b8e0ec80abee0a911606aee3cb.pdf
# 1845 https://openreview.net/pdf/02ebef063a90b11ff119d9060c607d167dcf56f0.pdf
# 1846 https://openreview.net/pdf/11c903fb0ae7779e4ea56f48250d4d3d5f2d0682.pdf
# 1847 https://openreview.net/pdf/283db14f7b0ab7536d7e7c4af7737d0af8bb879e.pdf
# 1848 https://openreview.net/pdf/4d45a848563fe0a005d13ebec5a38df41a0b15ff.pdf
# 1849 https://openreview.net/pdf/126bd01ad936e8852ca2745a2daa792beb9215b0.pdf
# 1850 https://openreview.net/pdf/d4583ed9950038851f3958f10032974d4dcd679d.pdf
# 1851 https://openreview.net/pdf/a3b3f825344de0536ec200e556e03d3bbffece49.pdf
# 1852 https://openreview.net/pdf/2225f9b1a14f1f5ecec1d0f959ce0ac6eae9e56f.pdf
# 1853 https://openreview.net/pdf/364f994fca777407147285d043b7b39cb223a083.pdf
# 1854 https://openreview.net/pdf/9a344c200fad5a8cfeb4953d1caf2138682d2a53.pdf
# 1855 https://openreview.net/pdf/6bad3008665ed39aee60079bbdd470a4d6c0a04f.pdf
# 1856 https://openreview.net/pdf/a062f0356d30c8c23d8c9dfc66870f9fd64d2bad.pdf
# 1857 https://openreview.net/pdf/d0cb9c68cdf04af18128af8dafc985e43f135d99.pdf
# 1858 https://openreview.net/pdf/8e424c8cdf88e077ba6d3d7007a1bba2bd575f0b.pdf
# 1859 https://openreview.net/pdf/916bd547510f5d8e329f209f7ed060d4d92b45ee.pdf
# 1860 https://openreview.net/pdf/d07d05fa5263c95e3450eef1395bf15e4bda464a.pdf
# 1861 https://openreview.net/pdf/350a322e9d7ce678be86a7e349969f99c71ac9ed.pdf
# 1862 https://openreview.net/pdf/bc117919562a4ccddbe5c5b24ee364d14289cdee.pdf
# 1863 https://openreview.net/pdf/fcf1d34c0463c5072ee49ce930224e980675829b.pdf
# 1864 https://openreview.net/pdf/1d69a358c61f60c745785ccb135c68f386cab985.pdf
# 1865 https://openreview.net/pdf/27e468b79e6a0dce391ffeee4e42a84ec5a74f18.pdf
# 1866 https://openreview.net/pdf/fcbfd7f8d46076e87300ed63c39d60a6e8c11a7e.pdf
# 1867 https://openreview.net/pdf/91d206421128fe583503be8c9d1f5daa8a37569d.pdf
# 1868 https://openreview.net/pdf/a963012277d0be951a9de8f97b5eaf12f29ecfe1.pdf
# 1869 https://openreview.net/pdf/d721a44b48bd9e0406aeb2cdcb2467e0c27748b9.pdf
# 1870 https://openreview.net/pdf/d875ba2409ec78faf50cee666b3866b2b99b54f8.pdf
# 1871 https://openreview.net/pdf/870710f79e8b381a737ed6e54fc559217331d74e.pdf
# 1872 https://openreview.net/pdf/89578ece1e09bb9f8db3ab2fc3cb6060315e84e1.pdf
# 1873 https://openreview.net/pdf/14d4373bb6d2984765594793abe2faf2ceb80a89.pdf
# 1874 https://openreview.net/pdf/6b88930a2f4b17b072ce937d41b10c43e6d346fd.pdf
# 1875 https://openreview.net/pdf/8887f249acf345628ee7b7c06fe8b3c9b46fb676.pdf
# 1876 https://openreview.net/pdf/15c3ba2e8d93b0f564409d605b0c09de23854938.pdf
# 1877 https://openreview.net/pdf/5d905ba0289cbac9fe40bf8cd02c7aa8f1d15fed.pdf
# 1878 https://openreview.net/pdf/4bf614d9277dc7ba7ec87eb0ccfccf6b765d3979.pdf
# 1879 https://openreview.net/pdf/8d132f07c57d5dc18a48663f3d168dad93109048.pdf
# 1880 https://openreview.net/pdf/2c6db8a4ff69ca681456fe5e686ec86f942d3e12.pdf
# 1881 https://openreview.net/pdf/2e72e0d2c26565539d7d40dc1983c1e9910cecf8.pdf
# 1882 https://openreview.net/pdf/e2a317b132c99a3518d708b154c2d550c894fb6d.pdf
# 1883 https://openreview.net/pdf/49daae6857ec6081fb601a7d52ee250678367588.pdf
# 1884 https://openreview.net/pdf/b9abe7307de1095b3383a26ddb780ebe0be496dd.pdf
# 1885 https://openreview.net/pdf/ffb89454a92c83824e2754db20f608d907ce4731.pdf
# 1886 https://openreview.net/pdf/df45080f396a3c8380dc08d984b22014cd1aa284.pdf
# 1887 https://openreview.net/pdf/6bd835569a1b61f49618d984d777598c8a177a3e.pdf
# 1888 https://openreview.net/pdf/8ee969e306496a349093b6c516778cfefd5e063c.pdf
# 1889 https://openreview.net/pdf/52f8255259dcb7f8c7eb512127836cadc58ea516.pdf
# 1890 https://openreview.net/pdf/6b162701a99cd8c53df853355fc0852ceb5167a4.pdf
# 1891 https://openreview.net/pdf/03b6d94b2d2e9c1cb0954a4dfb9c39c48b8e5ea9.pdf
# 1892 https://openreview.net/pdf/9be29f80c731191c05d1c4406577008f3bdca800.pdf
# 1893 https://openreview.net/pdf/839a14d5e04b5d93f17f573b7b8ec27dc68b14a8.pdf
# 1894 https://openreview.net/pdf/1416e2ba752ad66f387906f61f97cf4ab91dbce4.pdf
# 1895 https://openreview.net/pdf/78c7fb939078a784f02006f7272c92a758e1e9c7.pdf
# 1896 https://openreview.net/pdf/5c3b931a2ec95485109fb9613b8688f94d87eda1.pdf
# 1897 https://openreview.net/pdf/ad011e948fd7b2e72ff6dd869898255569519076.pdf
# 1898 https://openreview.net/pdf/5271e1e1fa036e2a4d63867e647bd9e65de2a2c2.pdf
# 1899 https://openreview.net/pdf/78861f841a343b5b3429f441b7fee815fd864524.pdf
# 1900 https://openreview.net/pdf/da8b6fd7f6b624d5851c386395325541be03d90e.pdf
# 1901 https://openreview.net/pdf/ecca3bb50360f2bfdefc54b78cbfbed715794c93.pdf
# 1902 https://openreview.net/pdf/52ae10abd4c4ec27aa37e7b394ebeea1c26dc625.pdf
# 1903 https://openreview.net/pdf/51a6f57de280cd08d584ebf7d65e42f4a9832852.pdf
# 1904 https://openreview.net/pdf/9dfc2ae9e672bdd44ff589054c88b18924af8483.pdf
# 1905 https://openreview.net/pdf/5061b4734d8106279a7df77c1c371b783e126e4e.pdf
# 1906 https://openreview.net/pdf/2f51ce0e41434fa7eac1af155e6ce6dbd0234098.pdf
# 1907 https://openreview.net/pdf/dc2578c49b3cfc78beece0602f3564947a512c18.pdf
# 1908 https://openreview.net/pdf/9fc2c719bd692cabc976c059c371b5de2e03fb30.pdf
# 1909 https://openreview.net/pdf/d3c3ae4103b11edd01a76154cea2c89f273250f0.pdf
# 1910 https://openreview.net/pdf/5c2ca8ce02a61aa8d6a258fe5b0a3fcd2d36c2b3.pdf
# 1911 https://openreview.net/pdf/adcda390b02e60272ebbb8d482c30df9a28a4c8c.pdf
# 1912 https://openreview.net/pdf/4a394f58d3c8affdb97174ec64d61e6a6f8ec462.pdf
# 1913 https://openreview.net/pdf/23f3b31eae45a21349ad7d90fe16f9e3add566ea.pdf
# 1914 https://openreview.net/pdf/532ff2212422b5d84ab3c53c0201604d36379515.pdf
# 1915 https://openreview.net/pdf/8b35edfa19ea168110ec1e0acfa6ecb8cd06a735.pdf
# 1916 https://openreview.net/pdf/c6954cdda97864dacce3dd9caa1900752b4a776c.pdf
# 1917 https://openreview.net/pdf/ba3ad1d1f754d30b7ce210a7b9c4d169705d5234.pdf
# 1918 https://openreview.net/pdf/de07bb8709651bf73dcec7308c3610ce657af47a.pdf
# 1919 https://openreview.net/pdf/65c63b72201856c7d08ce81fba8f12b50947aa77.pdf
# 1920 https://openreview.net/pdf/06e1637d0d7663914cdffbde335804a2f37b878c.pdf
# 1921 https://openreview.net/pdf/739b8d7a36ec0e20701ec29391fe2280b5bcfd98.pdf
# 1922 https://openreview.net/pdf/07b24e78b9fb4204ce847a464a1c84830f82b943.pdf
# 1923 https://openreview.net/pdf/1db5b6bc76f7aeb4bc36d1509dae0aabd19cb491.pdf
# 1924 https://openreview.net/pdf/783fa7b5b3e05731f96c26e3d4d84bf5842de072.pdf
# 1925 https://openreview.net/pdf/ebb7836265aef87bb9ac7eb2a88c75408c44b88b.pdf
# 1926 https://openreview.net/pdf/a649663271ca047d86bebd8b9d20f91d9eefbdb3.pdf
# 1927 https://openreview.net/pdf/a057d061dce08b6196f98519eeb910da2526caad.pdf
# 1928 https://openreview.net/pdf/4f9144ae0575dd9d1f9540d83426f7bb82540756.pdf
# 1929 https://openreview.net/pdf/5af17fbafcba261932381990540df8840ffec3f0.pdf
# 1930 https://openreview.net/pdf/3dd1ab41e4baf736ac0db3b0e6a3ba3971e9d042.pdf
# 1931 https://openreview.net/pdf/406ee084bb8f0247b906b0b194bf1f0315cb7867.pdf
# 1932 https://openreview.net/pdf/937b09777ff28114e273de706caa79125d73d894.pdf
# 1933 https://openreview.net/pdf/ac14c4b70b2efd3b6c4e244137ae56017267bf5d.pdf
# 1934 https://openreview.net/pdf/2fdbed9d5e9a10bb133efa481ccb570d71b8feba.pdf
# 1935 https://openreview.net/pdf/5faf31f7ae8da1dc54b3a2801eb83f27ea5f88e0.pdf
# 1936 https://openreview.net/pdf/971c9a6302832063d4fc1590b444b3ccd8f33e44.pdf
# 1937 https://openreview.net/pdf/63a91ca98681923ceee596aa7d3254f49445c743.pdf
# 1938 https://openreview.net/pdf/46d7353b95ccb2f191e0a6114b364ec4aade96e2.pdf
# 1939 https://openreview.net/pdf/1e1a4cfb8344c8fdb4e14ea567cdc6e5a3bb0301.pdf
# 1940 https://openreview.net/pdf/439bee65f721160a93f040f8600c3635de5e058a.pdf
# 1941 https://openreview.net/pdf/5140f8a3536ff05fe390f18c2d39ea155b0dbd18.pdf
# 1942 https://openreview.net/pdf/369464b615529909012f17d4e726319756e4de52.pdf
# 1943 https://openreview.net/pdf/24dd9f66ee9d2c057f311ec049f472bba267266c.pdf
# 1944 https://openreview.net/pdf/02e52806becd7a5141a476559faa9aec1b67bdce.pdf
# 1945 https://openreview.net/pdf/e6852d6a9b749e54b195047d6910e5c27fa9474a.pdf
# 1946 https://openreview.net/pdf/8a47190a33890c3b90463d493dc6f9bb78af91ee.pdf
# 1947 https://openreview.net/pdf/9b81b6bf8b97b50f030019d90c1ab1848a4407a0.pdf
# 1948 https://openreview.net/pdf/09b973c9c84fd934195e0c087cb7af065e9c6829.pdf
# 1949 https://openreview.net/pdf/256d09777da4f2cd48d3db5b59780044da48a958.pdf
# 1950 https://openreview.net/pdf/4c91ec48b89ce6f6d8504f69ae9036330c105901.pdf
# 1951 https://openreview.net/pdf/fd0e07fc837555ae3a7254d18b51bd091b998332.pdf
# 1952 https://openreview.net/pdf/760207455793019468b1695bd64f24537a7765bc.pdf
# 1953 https://openreview.net/pdf/8b67f407d22905f08e467f5c91f96f9eb5c64a19.pdf
# 1954 https://openreview.net/pdf/6bd69a4ef1e97f9382a07ee51b7286352318d746.pdf
# 1955 https://openreview.net/pdf/7d11fa19dba6ded5a08401f9ec44a4d3a03b07b8.pdf
# 1956 https://openreview.net/pdf/a37529acd82ddfd4751126ad44a499fb38c9e1d2.pdf
# 1957 https://openreview.net/pdf/f6ca61bd1897c2775d3df0ecb383f710a3911c55.pdf
# 1958 https://openreview.net/pdf/df1d40b1c077f27e1bc6b520a058ce60018e288e.pdf
# 1959 https://openreview.net/pdf/7c0fa9125fa53c842a7c216fd9f1b16ee517710f.pdf
# 1960 https://openreview.net/pdf/e0f67e22108de8d6be84c75330ee0de82ed3ae5a.pdf
# 1961 https://openreview.net/pdf/fcaa69d5aae6afe2bc1093525d8040992a2a38fd.pdf
# 1962 https://openreview.net/pdf/8b89e7d633833aae6b6595c02ad7370b9c920784.pdf
# 1963 https://openreview.net/pdf/dc43e5fd99a5392aedf0a73a5a11819a2d7ec708.pdf
# 1964 https://openreview.net/pdf/9f7784562cd53ab7d908c93bc8ece8b40dcaa922.pdf
# 1965 https://openreview.net/pdf/e8ccd3496e72d4a226d4b4bd59ea2c8d8aca263f.pdf
# 1966 https://openreview.net/pdf/1894212aa0d569da67f267b254d9fb5f83683a10.pdf
# 1967 https://openreview.net/pdf/87b5e2364079fd7058bb7d35c0e8ef7a79f539f5.pdf
# 1968 https://openreview.net/pdf/c0039b8a546d44b99398d9abce2db222d427a9b5.pdf
# 1969 https://openreview.net/pdf/a047012e007b5c21473d771f185012a4990d8ff9.pdf
# 1970 https://openreview.net/pdf/5e9f00255cce370f6775a942b9adf4fbcb67ca31.pdf
# 1971 https://openreview.net/pdf/eb31d33cc822a207f57944f6109846cb39df6244.pdf
# 1972 https://openreview.net/pdf/7fb3c4eed318cb32b972d300fb5fe64530416a25.pdf
# 1973 https://openreview.net/pdf/f089e06582d6aa8804f308b5b0d27d432cdb6b26.pdf
# 1974 https://openreview.net/pdf/d210fced5bf1ca06dc521b5bd8088e97ffbdc31e.pdf
# 1975 https://openreview.net/pdf/d7d02dd6dabc4d4c6316bdd7b17ef0748ca284b6.pdf
# 1976 https://openreview.net/pdf/8895967b0a0cc46d0f4328a9c58e36e5da0fec6b.pdf
# 1977 https://openreview.net/pdf/a513030b29e367c181e3cef2554754e8e2377c31.pdf
# 1978 https://openreview.net/pdf/1a807d3c6aaf49cf6c427a875391c4ff433565ae.pdf
# 1979 https://openreview.net/pdf/1a6a51cca7a2ea73f90c196c36acc67428f471a7.pdf
# 1980 https://openreview.net/pdf/74ca24ef24231925d9c78ad8020a8a97597cf504.pdf
# 1981 https://openreview.net/pdf/0687b4a8e08bdcb968a582cbb3d8b8ae7047397b.pdf
# 1982 https://openreview.net/pdf/858241f6c2561f8e00321e85c01eb1c15f18be15.pdf
# 1983 https://openreview.net/pdf/b3f85b26464b6cd916b9a66adb82d3d295c951c4.pdf
# 1984 https://openreview.net/pdf/d69e38ce0133248c3aa4891495115f8f59ccc7a5.pdf
# 1985 https://openreview.net/pdf/836416358c35826ddb12f100d55e28a66973ef30.pdf
# 1986 https://openreview.net/pdf/b78fc86a974c00f6de41f020cb18d63af427fa50.pdf
# 1987 https://openreview.net/pdf/091c17fd6f404b8113013961edf9e51c142612a5.pdf
# 1988 https://openreview.net/pdf/2e082778e9c948cf856dc93b13cc4d0734583c61.pdf
# 1989 https://openreview.net/pdf/31fba2ce53b7314f1c3b3ec7719c818d82414a6d.pdf
# 1990 https://openreview.net/pdf/7f1f1fe99b0a6573e1aedf2765a68f9b4f8504ea.pdf
# 1991 https://openreview.net/pdf/a0c8d10b1b415c591443cffbd8a763cfb7f55124.pdf
# 1992 https://openreview.net/pdf/a44a46ea8deb0fda30f91b5e7a0712d7544a462a.pdf
# 1993 https://openreview.net/pdf/c87a709549b094b57c4b4590d248a1f077c87864.pdf
# 1994 https://openreview.net/pdf/e859805a821a58192c61c0d40ef8d9237c73ed8d.pdf
# 1995 https://openreview.net/pdf/d9faf18178849548aa48ad60be796c8cf4d5dad0.pdf
# 1996 https://openreview.net/pdf/36da61de359dcd3bc4c160b4e80f896874537819.pdf
# 1997 https://openreview.net/pdf/c696823e1ca79064841583eacf0580cc3587aabb.pdf
# 1998 https://openreview.net/pdf/9f8fc08ed653c3511babee63e9f40cb240dab2f0.pdf
# 1999 https://openreview.net/pdf/51ff29f8a5e041d9c49dd999d003df46a0b1a5ea.pdf

# %%
# @title Zip all the pdfs (to local, no need)
import zipfile
import os


path_folder = working_dir + "files/paper_pdf/"
path_zip = path_folder + "paper.zip"

file_paths = []
for root, _, files in os.walk(path_folder):
    for file in files:
        if file.endswith("zip"):
            print(file)
            raise(Exception)
        file_paths.append(path_folder + file)

with zipfile.ZipFile(path_zip, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file in tqdm(file_paths, desc="Zipping files"):
        zipf.write(file)
# Out:
# Zipping files:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
# @title Parse Papers
import argparse
import threading
import time
import sys
import pandas as pd
import json
import os
import requests

import PyPDF2
import zipfile

parser = argparse.ArgumentParser()
# which context, see folder '../openreview/' for openreview and '../yelp/' for yelp
parser.add_argument("--context", type=str, default="openreview")
# which dataset, use 'rl' for openreview and 'pizza' for yelp.
parser.add_argument("--dataset", type=str, required=True)
args = parser.parse_args(["--dataset", "rand1000"])

with open(working_dir+"paper_"+args.dataset+".json", "r") as json_file:
    papers = json.load(json_file)
with open(working_dir+"review_"+args.dataset+".json", "r") as json_file:
    reviews = json.load(json_file)

if __name__ == "__main__":

    # DO NOT USE PYPDF TO PARSE PAPERS
    # USE SCIENCEBEAM INSTEAD
    # (This is because pypdf returns dummy texts, which will lead the raw paper to be too long)
    if False:

        for i, paper in enumerate(papers):

            if i>5: break

            path_pdf = working_dir + "files/paper_pdf/" + paper["id"] + ".pdf"
            path_raw = working_dir + "files/paper_raw/" + paper["id"] + ".txt"

            if not os.path.exists(path_pdf):
                print("error")
                exit(0)

            def parse_pdf(path_pdf):
                text = ""
                with open(path_pdf, 'rb') as file:
                    pdf_reader = PyPDF2.PdfReader(file)
                    num_pages = len(pdf_reader.pages)
                    for page_num in range(num_pages):
                        page = pdf_reader.pages[page_num]
                        text += page.extract_text()
                return text

            text = parse_pdf(path_pdf)
            with open(path_raw, "w") as file:
                file.write(text)

    else:
        path_zip = working_dir + "files/paper_raw.zip"
        path_folder = working_dir + "files/paper_raw/"
        with zipfile.ZipFile(path_zip, 'r') as zip_ref:
            zip_ref.extractall(path_folder)

# %%
# @title Build Refined Dataset
import json
import random
import argparse
import pandas as pd
from tqdm.notebook import tqdm

parser = argparse.ArgumentParser()
# which context, see folder '../openreview/' for openreview and '../yelp/' for yelp
parser.add_argument("--context", type=str, default="openreview")
parser.add_argument("--dataset", type=str, required=True)
args = parser.parse_args(["--dataset", "rand2000"])

with open(working_dir+"paper_"+args.dataset+".json", "r") as json_file:
    papers = json.load(json_file)
with open(working_dir+"review_"+args.dataset+".json", "r") as json_file:
    reviews = json.load(json_file)

mp = {}
for review in reviews:
    if review["belong_id"] not in mp:
        mp[review["belong_id"]] = []
    mp[review["belong_id"]].append(review["review"])

assert(len(mp)==2000)
cnt = 0
for (paper_id, reviews) in mp.items():
    assert(len(reviews) >= 3)
    random.seed(19260817 + cnt)
    cnt += 1
    random.shuffle(reviews)

df = pd.DataFrame(columns=["paper_id", "pdf_url", "abstract", "parsed_text","human_review1","human_review2","human_review3"])
for i, paper in enumerate(tqdm(papers, desc="Processing Papers")):
    pdf_url = "https://openreview.net" + paper["pdf"]
    with open(working_dir + "files/paper_raw/" + paper["id"] + ".txt", "r", encoding="utf-8") as f:
        parsed_text = f.read()
    df.loc[len(df)] = [paper["id"], pdf_url, paper["abstract"], parsed_text, mp[paper["id"]][0],mp[paper["id"]][1],mp[paper["id"]][2]]
# df.to_json(dataset_dir + 'dataset_paper.json', index=False)
df.to_parquet(dataset_dir + 'dataset_paper.parquet', index=False)

# %%
import pandas as pd
dataset_paper = pd.read_parquet(dataset_dir + "dataset_paper.parquet")

for i in range(len(dataset_paper)):
        row = dataset_paper.loc[i]
        if len(row["parsed_text"]) < 1000:
            print(i, row["paper_id"], len(row["parsed_text"]))
